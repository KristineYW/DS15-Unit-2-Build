# %% [markdown]
# <a href="https://colab.research.google.com/github/KristineYW/DS-Unit-2-Applied-Modeling/blob/master/Kristine_Wang_LS_DS_232_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Your code starts here:

# %%
# Read in csv

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sc1 = pd.read_csv('https://raw.githubusercontent.com/KristineYW/DS-Unit-2-Applied-Modeling/master/SCDB_2019_01_justiceCentered_LegalProvision_1.csv', encoding = "ISO-8859-1")

sc1.head()
# Out:
#      caseId     docketId                voteId dateDecision  decisionType  \
# 0  1946-001  1946-001-01  1946-001-01-01-01-01     11/18/46             1
# 1  1946-001  1946-001-01  1946-001-01-01-01-02     11/18/46             1
# 2  1946-001  1946-001-01  1946-001-01-01-01-03     11/18/46             1
# 3  1946-001  1946-001-01  1946-001-01-01-01-04     11/18/46             1
# 4  1946-001  1946-001-01  1946-001-01-01-01-05     11/18/46             1
#
#        ledCite  term  naturalCourt   chief docket  ... Unnamed: 47  \
# 0  91 L. Ed. 3  1946          1301  Vinson     24  ...         NaN
# 1  91 L. Ed. 3  1946          1301  Vinson     24  ...         NaN
# 2  91 L. Ed. 3  1946          1301  Vinson     24  ...         NaN
# 3  91 L. Ed. 3  1946          1301  Vinson     24  ...         NaN
# 4  91 L. Ed. 3  1946          1301  Vinson     24  ...         NaN
#
#   Unnamed: 48 Unnamed: 49  Unnamed: 50  Unnamed: 51  Unnamed: 52  Unnamed: 53  \
# 0         NaN         NaN          NaN          NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 54  firstAgreement  secondAgreement
# 0          NaN             NaN              NaN
# 1          NaN             NaN              NaN
# 2          NaN             NaN              NaN
# 3          NaN             NaN              NaN
# 4          NaN             NaN              NaN
#
# [5 rows x 57 columns]

# %%
sc2 = pd.read_csv('https://raw.githubusercontent.com/KristineYW/DS-Unit-2-Applied-Modeling/master/SCDB_2019_01_justiceCentered_LegalProvision_2.csv', encoding = "ISO-8859-1")

sc2.head()
# Out:
#    ï»¿certReason  lcDisposition  lcDispositionDirection  declarationUncon  \
# 0           11.0            2.0                     1.0               1.0
# 1           11.0            2.0                     1.0               1.0
# 2           11.0            2.0                     1.0               1.0
# 3           11.0            2.0                     1.0               1.0
# 4           11.0            2.0                     1.0               1.0
#
#    caseDisposition  caseDispositionUnusual  partyWinning  precedentAlteration  \
# 0              3.0                     0.0           1.0                  1.0
# 1              3.0                     0.0           1.0                  1.0
# 2              3.0                     0.0           1.0                  1.0
# 3              3.0                     0.0           1.0                  1.0
# 4              3.0                     0.0           1.0                  1.0
#
#    voteUnclear    issue  ...  majOpinAssigner  splitVote  majVotes  minVotes  \
# 0          0.0  80180.0  ...             78.0          1         8         1
# 1          0.0  80180.0  ...             78.0          1         8         1
# 2          0.0  80180.0  ...             78.0          1         8         1
# 3          0.0  80180.0  ...             78.0          1         8         1
# 4          0.0  80180.0  ...             78.0          1         8         1
#
#    justice   justiceName  vote opinion  direction  majority
# 0       86      HHBurton   2.0     1.0        1.0       1.0
# 1       84     RHJackson   1.0     1.0        2.0       2.0
# 2       81     WODouglas   1.0     1.0        2.0       2.0
# 3       80  FFrankfurter   4.0     2.0        2.0       2.0
# 4       79        SFReed   1.0     1.0        2.0       2.0
#
# [5 rows x 29 columns]

# %%
# Join the two large datasets into one dataframe

sc = pd.concat([sc1,sc2], axis=1)

sc.head()
# Out:
#      caseId     docketId                voteId dateDecision  decisionType  \
# 0  1946-001  1946-001-01  1946-001-01-01-01-01     11/18/46             1
# 1  1946-001  1946-001-01  1946-001-01-01-01-02     11/18/46             1
# 2  1946-001  1946-001-01  1946-001-01-01-01-03     11/18/46             1
# 3  1946-001  1946-001-01  1946-001-01-01-01-04     11/18/46             1
# 4  1946-001  1946-001-01  1946-001-01-01-01-05     11/18/46             1
#
#        ledCite  term  naturalCourt   chief docket  ... majOpinAssigner  \
# 0  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 1  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 2  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 3  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 4  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
#
#   splitVote majVotes  minVotes  justice   justiceName  vote  opinion  \
# 0         1        8         1       86      HHBurton   2.0      1.0
# 1         1        8         1       84     RHJackson   1.0      1.0
# 2         1        8         1       81     WODouglas   1.0      1.0
# 3         1        8         1       80  FFrankfurter   4.0      2.0
# 4         1        8         1       79        SFReed   1.0      1.0
#
#    direction  majority
# 0        1.0       1.0
# 1        2.0       2.0
# 2        2.0       2.0
# 3        2.0       2.0
# 4        2.0       2.0
#
# [5 rows x 86 columns]

# %%
sc = sc.drop(['Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 
              'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 
              'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 
              'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 
              'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 
              'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54'], axis=1)

sc.head()
# Out:
#      caseId     docketId                voteId dateDecision  decisionType  \
# 0  1946-001  1946-001-01  1946-001-01-01-01-01     11/18/46             1
# 1  1946-001  1946-001-01  1946-001-01-01-01-02     11/18/46             1
# 2  1946-001  1946-001-01  1946-001-01-01-01-03     11/18/46             1
# 3  1946-001  1946-001-01  1946-001-01-01-01-04     11/18/46             1
# 4  1946-001  1946-001-01  1946-001-01-01-01-05     11/18/46             1
#
#        ledCite  term  naturalCourt   chief docket  ... majOpinAssigner  \
# 0  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 1  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 2  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 3  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 4  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
#
#   splitVote majVotes  minVotes  justice   justiceName  vote  opinion  \
# 0         1        8         1       86      HHBurton   2.0      1.0
# 1         1        8         1       84     RHJackson   1.0      1.0
# 2         1        8         1       81     WODouglas   1.0      1.0
# 3         1        8         1       80  FFrankfurter   4.0      2.0
# 4         1        8         1       79        SFReed   1.0      1.0
#
#    direction  majority
# 0        1.0       1.0
# 1        2.0       2.0
# 2        2.0       2.0
# 3        2.0       2.0
# 4        2.0       2.0
#
# [5 rows x 57 columns]

# %%
import datetime

# %%
sc['dateDecision'][7]
# Out:
# '11/18/46'

# %%
sc.sample(10)
# Out:
#           caseId     docketId                voteId dateDecision  \
# 11260   1952-002  1952-002-01  1952-002-01-01-01-03     10/20/52
# 104205  2001-031  2001-031-01  2001-031-01-01-01-05      3/19/02
# 87681   1988-118  1988-118-01  1988-118-01-01-01-05      6/15/89
# 5821    1948-079  1948-079-01  1948-079-01-01-01-08      5/31/49
# 117730  2015-024  2015-024-01  2015-024-01-01-01-07       3/1/16
# 19532   1957-072  1957-072-01  1957-072-01-01-01-09      3/31/58
# 34707   1965-026  1965-026-04  1965-026-04-05-01-08      12/7/65
# 97100   1995-007  1995-007-01  1995-007-01-01-01-06     11/28/95
# 6065    1948-096  1948-096-01  1948-096-01-01-01-09      6/20/49
# 911     1946-051  1946-051-01  1946-051-01-03-01-03      2/10/47
#
#         decisionType            ledCite  term  naturalCourt      chief  \
# 11260              2     97 L. Ed. 2d 4  1952          1303     Vinson
# 104205             1  152 L. Ed. 2d 188  2001          1607  Rehnquist
# 87681              6  105 L. Ed. 2d 218  1988          1603  Rehnquist
# 5821               1  93 L. Ed. 2d 1226  1948          1301     Vinson
# 117730             1   194 L. Ed. 2d 20  2015          1705    Roberts
# 19532              7    2 L. Ed. 2d 630  1957          1405     Warren
# 34707              1   15 L. Ed. 2d 284  1965          1409     Warren
# 97100              1  133 L. Ed. 2d 371  1995          1607  Rehnquist
# 6065               1  93 L. Ed. 2d 1480  1948          1301     Vinson
# 911                1      91 L. Ed. 794  1946          1301     Vinson
#
#          docket  ... majOpinAssigner splitVote majVotes  minVotes  justice  \
# 11260       126  ...             NaN         1        8         1       86
# 104205  00-1072  ...           102.0         1        9         0      106
# 87681   87-6997  ...           102.0         1        9         0      102
# 5821       269M  ...            87.0         1        7         2       82
# 117730   14-181  ...           111.0         1        6         2      113
# 19532        70  ...            90.0         1        5         4       86
# 34707        32  ...            90.0         1        7         1       88
# 97100    94-947  ...           102.0         1        9         0      107
# 6065        390  ...            78.0         1        6         2       87
# 911          84  ...            87.0         1        5         2       81
#
#         justiceName  vote  opinion  direction  majority
# 11260      HHBurton   1.0      1.0        1.0       2.0
# 104205    AMKennedy   1.0      1.0        2.0       2.0
# 87681   WHRehnquist   1.0      1.0        2.0       2.0
# 5821        FMurphy   1.0      1.0        1.0       2.0
# 117730   SSotomayor   2.0      1.0        1.0       1.0
# 19532      HHBurton   2.0      1.0        1.0       1.0
# 34707       TCClark   1.0      1.0        1.0       2.0
# 97100      DHSouter   1.0      1.0        2.0       2.0
# 6065       FMVinson   NaN      NaN        NaN       NaN
# 911       WODouglas   1.0      1.0        1.0       2.0
#
# [10 rows x 57 columns]

# %%
sc['justiceName'].value_counts()
# Out:
# WJBrennan       8183
# BRWhite         7555
# WHRehnquist     6778
# WODouglas       6318
# JPStevens       6288
# TMarshall       5949
# HABlackmun      5712
# PStewart        5506
# HLBlack         5280
# SDOConnor       4298
# WEBurger        4258
# LFPowell        4070
# AScalia         4020
# AMKennedy       3951
# JHarlan2        3627
# TCClark         3554
# EWarren         3405
# CThomas         3228
# FFrankfurter    3107
# RBGinsburg      2878
# SGBreyer        2739
# DHSouter        2434
# HHBurton        2327
# SFReed          1942
# RHJackson       1587
# FMVinson        1442
# JGRoberts       1357
# SAAlito         1326
# SMinton         1158
# CEWhittaker     1065
# SSotomayor       955
# AFortas          951
# EKagan           838
# FMurphy          723
# WBRutledge       723
# AJGoldberg       718
# NMGorsuch        228
# BMKavanaugh       80
# Name: justiceName, dtype: int64

# %%
# Change dateDecision to datetime data type 


def yearConvert(date):
    year_int = int(date[-2:])
    if year_int > 20:
        edited_str = date[:-2] + '19' + date[-2:]
    else:
        edited_str = date[:-2] + '20' + date[-2:]
    return(pd.to_datetime(edited_str))
sc['dateDecision'] = [yearConvert(i) for i in sc['dateDecision']]
sc['dateDecision'].describe
# Out:
# <bound method NDFrame.describe of 0        1946-11-18
# 1        1946-11-18
# 2        1946-11-18
# 3        1946-11-18
# 4        1946-11-18
#             ...
# 120553   2019-05-28
# 120554   2019-05-28
# 120555   2019-05-28
# 120556   2019-05-28
# 120557   2019-05-28
# Name: dateDecision, Length: 120558, dtype: datetime64[ns]>

# %%
# Introduce new features for senate majority party and presidential party


sc['partyOfPresident'] = np.where((sc['dateDecision'] < '1953-01-19') | ('1961-01-20' < sc['dateDecision']) & (sc['dateDecision'] < '1969-01-19') | 
                                  ('1977-01-20' < sc['dateDecision']) & (sc['dateDecision'] < '1981-01-19') | 
                                  ('1993-01-20' < sc['dateDecision']) & (sc['dateDecision'] < '2001-01-19') | 
                                  ('2009-01-20' < sc['dateDecision']) & (sc['dateDecision'] < '2017-01-20'), 
                                  'Democrat','Republican')

# %%
sc['partyOfAppointing'] = np.where((sc['justiceName'] == 'BRWhite') | (sc['justiceName'] == 'WODouglas') | (sc['justiceName'] == 'Tmarshall') | 
                                (sc['justiceName'] == 'HLBlack') | (sc['justiceName'] == 'TCClark') | (sc['justiceName'] == 'Ffrankfurter') | 
                                (sc['justiceName']== 'RBGinsburg') | (sc['justiceName'] == 'SGBreyer') | (sc['justiceName'] == 'HHBurton') | 
                                (sc['justiceName'] == 'SFReed') | (sc['justiceName'] == 'RHJackson') | (sc['justiceName'] == 'FMVinson') | 
                                (sc['justiceName'] == 'Sminton') | (sc['justiceName'] == 'Ssotomayor') | (sc['justiceName'] == 'Afortas') | 
                                (sc['justiceName'] == 'Ekagan') | (sc['justiceName'] == 'Fmurphy') | (sc['justiceName'] == 'WBRutledge') | 
                                (sc['justiceName'] == 'AJGoldberg'), 'Democrat','Republican' )

# %%
sc.head()
# Out:
#      caseId     docketId                voteId dateDecision  decisionType  \
# 0  1946-001  1946-001-01  1946-001-01-01-01-01   1946-11-18             1
# 1  1946-001  1946-001-01  1946-001-01-01-01-02   1946-11-18             1
# 2  1946-001  1946-001-01  1946-001-01-01-01-03   1946-11-18             1
# 3  1946-001  1946-001-01  1946-001-01-01-01-04   1946-11-18             1
# 4  1946-001  1946-001-01  1946-001-01-01-01-05   1946-11-18             1
#
#        ledCite  term  naturalCourt   chief docket  ... majVotes minVotes  \
# 0  91 L. Ed. 3  1946          1301  Vinson     24  ...        8        1
# 1  91 L. Ed. 3  1946          1301  Vinson     24  ...        8        1
# 2  91 L. Ed. 3  1946          1301  Vinson     24  ...        8        1
# 3  91 L. Ed. 3  1946          1301  Vinson     24  ...        8        1
# 4  91 L. Ed. 3  1946          1301  Vinson     24  ...        8        1
#
#   justice   justiceName  vote  opinion  direction  majority  partyOfPresident  \
# 0      86      HHBurton   2.0      1.0        1.0       1.0          Democrat
# 1      84     RHJackson   1.0      1.0        2.0       2.0          Democrat
# 2      81     WODouglas   1.0      1.0        2.0       2.0          Democrat
# 3      80  FFrankfurter   4.0      2.0        2.0       2.0          Democrat
# 4      79        SFReed   1.0      1.0        2.0       2.0          Democrat
#
#    partyOfAppointing
# 0           Democrat
# 1           Democrat
# 2           Democrat
# 3         Republican
# 4           Democrat
#
# [5 rows x 59 columns]

# %%
sc['partyOfPresident'].value_counts(normalize=True)
# Out:
# Republican    0.551909
# Democrat      0.448091
# Name: partyOfPresident, dtype: float64

# %%
sc['partyOfSenate'] = np.where((sc['dateDecision'] < '1947-01-03') | ('1949-01-03' < sc['dateDecision']) & (sc['dateDecision'] < '1953-01-02') | 
                                  ('1955-01-03' < sc['dateDecision']) & (sc['dateDecision'] < '1981-01-02') | 
                                  ('1987-01-03' < sc['dateDecision']) & (sc['dateDecision'] < '1995-01-02') |
                                  ('2001-01-03' < sc['dateDecision']) & (sc['dateDecision'] < '2002-11-11') | 
                                  ('2007-01-03' < sc['dateDecision']) & (sc['dateDecision'] < '2017-01-02'),
                                  'Democrat','Republican')

sc['partyOfSenate'].value_counts(normalize=True)
# Out:
# Democrat      0.712404
# Republican    0.287596
# Name: partyOfSenate, dtype: float64

# %%
sc.head()
# Out:
#      caseId     docketId                voteId dateDecision  decisionType  \
# 0  1946-001  1946-001-01  1946-001-01-01-01-01   1946-11-18             1
# 1  1946-001  1946-001-01  1946-001-01-01-01-02   1946-11-18             1
# 2  1946-001  1946-001-01  1946-001-01-01-01-03   1946-11-18             1
# 3  1946-001  1946-001-01  1946-001-01-01-01-04   1946-11-18             1
# 4  1946-001  1946-001-01  1946-001-01-01-01-05   1946-11-18             1
#
#        ledCite  term  naturalCourt   chief docket  ... minVotes justice  \
# 0  91 L. Ed. 3  1946          1301  Vinson     24  ...        1      86
# 1  91 L. Ed. 3  1946          1301  Vinson     24  ...        1      84
# 2  91 L. Ed. 3  1946          1301  Vinson     24  ...        1      81
# 3  91 L. Ed. 3  1946          1301  Vinson     24  ...        1      80
# 4  91 L. Ed. 3  1946          1301  Vinson     24  ...        1      79
#
#     justiceName  vote  opinion  direction  majority  partyOfPresident  \
# 0      HHBurton   2.0      1.0        1.0       1.0          Democrat
# 1     RHJackson   1.0      1.0        2.0       2.0          Democrat
# 2     WODouglas   1.0      1.0        2.0       2.0          Democrat
# 3  FFrankfurter   4.0      2.0        2.0       2.0          Democrat
# 4        SFReed   1.0      1.0        2.0       2.0          Democrat
#
#    partyOfAppointing  partyOfSenate
# 0           Democrat       Democrat
# 1           Democrat       Democrat
# 2           Democrat       Democrat
# 3         Republican       Democrat
# 4           Democrat       Democrat
#
# [5 rows x 60 columns]

# %%
pd.set_option('display.max_columns',100)
    
sc.head(10)
# Out:
#      caseId     docketId                voteId dateDecision  decisionType  \
# 0  1946-001  1946-001-01  1946-001-01-01-01-01   1946-11-18             1
# 1  1946-001  1946-001-01  1946-001-01-01-01-02   1946-11-18             1
# 2  1946-001  1946-001-01  1946-001-01-01-01-03   1946-11-18             1
# 3  1946-001  1946-001-01  1946-001-01-01-01-04   1946-11-18             1
# 4  1946-001  1946-001-01  1946-001-01-01-01-05   1946-11-18             1
# 5  1946-001  1946-001-01  1946-001-01-01-01-06   1946-11-18             1
# 6  1946-001  1946-001-01  1946-001-01-01-01-07   1946-11-18             1
# 7  1946-001  1946-001-01  1946-001-01-01-01-08   1946-11-18             1
# 8  1946-001  1946-001-01  1946-001-01-01-01-09   1946-11-18             1
# 9  1946-002  1946-002-01  1946-002-01-01-01-01   1946-11-18             1
#
#         ledCite  term  naturalCourt   chief docket  \
# 0   91 L. Ed. 3  1946          1301  Vinson     24
# 1   91 L. Ed. 3  1946          1301  Vinson     24
# 2   91 L. Ed. 3  1946          1301  Vinson     24
# 3   91 L. Ed. 3  1946          1301  Vinson     24
# 4   91 L. Ed. 3  1946          1301  Vinson     24
# 5   91 L. Ed. 3  1946          1301  Vinson     24
# 6   91 L. Ed. 3  1946          1301  Vinson     24
# 7   91 L. Ed. 3  1946          1301  Vinson     24
# 8   91 L. Ed. 3  1946          1301  Vinson     24
# 9  91 L. Ed. 12  1946          1301  Vinson     12
#
#                                             caseName dateArgument dateRearg  \
# 0  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 1  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 2  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 3  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 4  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 5  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 6  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 7  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 8  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 9                         CLEVELAND v. UNITED STATES     10/10/45  10/17/46
#
#    petitioner  petitionerState  respondent  respondentState  jurisdiction  \
# 0       198.0              NaN       172.0              NaN             6
# 1       198.0              NaN       172.0              NaN             6
# 2       198.0              NaN       172.0              NaN             6
# 3       198.0              NaN       172.0              NaN             6
# 4       198.0              NaN       172.0              NaN             6
# 5       198.0              NaN       172.0              NaN             6
# 6       198.0              NaN       172.0              NaN             6
# 7       198.0              NaN       172.0              NaN             6
# 8       198.0              NaN       172.0              NaN             6
# 9       100.0              NaN        27.0              NaN             1
#
#    adminAction  adminActionState  threeJudgeFdc  caseOrigin  caseOriginState  \
# 0          NaN               NaN            0.0        51.0              6.0
# 1          NaN               NaN            0.0        51.0              6.0
# 2          NaN               NaN            0.0        51.0              6.0
# 3          NaN               NaN            0.0        51.0              6.0
# 4          NaN               NaN            0.0        51.0              6.0
# 5          NaN               NaN            0.0        51.0              6.0
# 6          NaN               NaN            0.0        51.0              6.0
# 7          NaN               NaN            0.0        51.0              6.0
# 8          NaN               NaN            0.0        51.0              6.0
# 9          NaN               NaN            0.0       123.0             52.0
#
#    caseSource  caseSourceState  lcDisagreement  firstAgreement  \
# 0        29.0              NaN             0.0             NaN
# 1        29.0              NaN             0.0             NaN
# 2        29.0              NaN             0.0             NaN
# 3        29.0              NaN             0.0             NaN
# 4        29.0              NaN             0.0             NaN
# 5        29.0              NaN             0.0             NaN
# 6        29.0              NaN             0.0             NaN
# 7        29.0              NaN             0.0             NaN
# 8        29.0              NaN             0.0             NaN
# 9        30.0              NaN             0.0             NaN
#
#    secondAgreement  ï»¿certReason  lcDisposition  lcDispositionDirection  \
# 0              NaN           11.0            2.0                     1.0
# 1              NaN           11.0            2.0                     1.0
# 2              NaN           11.0            2.0                     1.0
# 3              NaN           11.0            2.0                     1.0
# 4              NaN           11.0            2.0                     1.0
# 5              NaN           11.0            2.0                     1.0
# 6              NaN           11.0            2.0                     1.0
# 7              NaN           11.0            2.0                     1.0
# 8              NaN           11.0            2.0                     1.0
# 9              NaN            4.0            2.0                     1.0
#
#    declarationUncon  caseDisposition  caseDispositionUnusual  partyWinning  \
# 0               1.0              3.0                     0.0           1.0
# 1               1.0              3.0                     0.0           1.0
# 2               1.0              3.0                     0.0           1.0
# 3               1.0              3.0                     0.0           1.0
# 4               1.0              3.0                     0.0           1.0
# 5               1.0              3.0                     0.0           1.0
# 6               1.0              3.0                     0.0           1.0
# 7               1.0              3.0                     0.0           1.0
# 8               1.0              3.0                     0.0           1.0
# 9               1.0              2.0                     0.0           0.0
#
#    precedentAlteration  voteUnclear    issue  issueArea  decisionDirection  \
# 0                  1.0          0.0  80180.0        8.0                2.0
# 1                  1.0          0.0  80180.0        8.0                2.0
# 2                  1.0          0.0  80180.0        8.0                2.0
# 3                  1.0          0.0  80180.0        8.0                2.0
# 4                  1.0          0.0  80180.0        8.0                2.0
# 5                  1.0          0.0  80180.0        8.0                2.0
# 6                  1.0          0.0  80180.0        8.0                2.0
# 7                  1.0          0.0  80180.0        8.0                2.0
# 8                  1.0          0.0  80180.0        8.0                2.0
# 9                  0.0          0.0  10500.0        1.0                1.0
#
#    decisionDirectionDissent  authorityDecision1  authorityDecision2  lawType  \
# 0                       0.0                 4.0                 NaN      6.0
# 1                       0.0                 4.0                 NaN      6.0
# 2                       0.0                 4.0                 NaN      6.0
# 3                       0.0                 4.0                 NaN      6.0
# 4                       0.0                 4.0                 NaN      6.0
# 5                       0.0                 4.0                 NaN      6.0
# 6                       0.0                 4.0                 NaN      6.0
# 7                       0.0                 4.0                 NaN      6.0
# 8                       0.0                 4.0                 NaN      6.0
# 9                       0.0                 4.0                 NaN      6.0
#
#    lawSupp          lawMinor  majOpinWriter  majOpinAssigner  splitVote  \
# 0    600.0   35 U.S.C. Ã 33           78.0             78.0          1
# 1    600.0   35 U.S.C. Ã 33           78.0             78.0          1
# 2    600.0   35 U.S.C. Ã 33           78.0             78.0          1
# 3    600.0   35 U.S.C. Ã 33           78.0             78.0          1
# 4    600.0   35 U.S.C. Ã 33           78.0             78.0          1
# 5    600.0   35 U.S.C. Ã 33           78.0             78.0          1
# 6    600.0   35 U.S.C. Ã 33           78.0             78.0          1
# 7    600.0   35 U.S.C. Ã 33           78.0             78.0          1
# 8    600.0   35 U.S.C. Ã 33           78.0             78.0          1
# 9    600.0  18 U.S.C. Ã 398           81.0             87.0          1
#
#    majVotes  minVotes  justice   justiceName  vote  opinion  direction  \
# 0         8         1       86      HHBurton   2.0      1.0        1.0
# 1         8         1       84     RHJackson   1.0      1.0        2.0
# 2         8         1       81     WODouglas   1.0      1.0        2.0
# 3         8         1       80  FFrankfurter   4.0      2.0        2.0
# 4         8         1       79        SFReed   1.0      1.0        2.0
# 5         8         1       78       HLBlack   1.0      2.0        2.0
# 6         8         1       85    WBRutledge   1.0      1.0        2.0
# 7         8         1       82       FMurphy   1.0      1.0        2.0
# 8         8         1       87      FMVinson   1.0      1.0        2.0
# 9         6         3       86      HHBurton   1.0      1.0        1.0
#
#    majority partyOfPresident partyOfAppointing partyOfSenate
# 0       1.0         Democrat          Democrat      Democrat
# 1       2.0         Democrat          Democrat      Democrat
# 2       2.0         Democrat          Democrat      Democrat
# 3       2.0         Democrat        Republican      Democrat
# 4       2.0         Democrat          Democrat      Democrat
# 5       2.0         Democrat          Democrat      Democrat
# 6       2.0         Democrat          Democrat      Democrat
# 7       2.0         Democrat        Republican      Democrat
# 8       2.0         Democrat          Democrat      Democrat
# 9       2.0         Democrat          Democrat      Democrat

# %%
sc['term'].value_counts()
# Out:
# 1967    2943
# 1986    2583
# 1946    2556
# 1975    2496
# 1973    2448
#         ...
# 2017     801
# 2007     790
# 2014     783
# 2016     747
# 2018     720
# Name: term, Length: 73, dtype: int64

# %%
# Retrain features to be categorical for OneHotEncoding

all_columns = list(sc)
sc[all_columns] = sc[all_columns].astype(str)

# %%
# Drop repetitive columns 

# sc = sc.drop(['caseName','ledCite','dateArgument','dateRearg'], axis=1)

# %%
sc['direction'].value_counts(normalize=True)
# Out:
# 2.0    0.496666
# 1.0    0.447419
# nan    0.055915
# Name: direction, dtype: float64

# %%
sc['direction'] = sc['direction'].replace({'nan':'-1'})

# %%
sc['direction'].value_counts(normalize=True)
# Out:
# 2.0    0.496666
# 1.0    0.447419
# -1     0.055915
# Name: direction, dtype: float64

# %%
sc['partyOfPresident'].value_counts(normalize=True)
# Out:
# Republican    0.551909
# Democrat      0.448091
# Name: partyOfPresident, dtype: float64

# %%
sc['partyOfSenate'].value_counts(normalize=True)
# Out:
# Democrat      0.712404
# Republican    0.287596
# Name: partyOfSenate, dtype: float64

# %%
sc.isnull().sum()
# Out:
# caseId                      0
# docketId                    0
# voteId                      0
# dateDecision                0
# decisionType                0
# ledCite                     0
# term                        0
# naturalCourt                0
# chief                       0
# docket                      0
# caseName                    0
# dateArgument                0
# dateRearg                   0
# petitioner                  0
# petitionerState             0
# respondent                  0
# respondentState             0
# jurisdiction                0
# adminAction                 0
# adminActionState            0
# threeJudgeFdc               0
# caseOrigin                  0
# caseOriginState             0
# caseSource                  0
# caseSourceState             0
# lcDisagreement              0
# firstAgreement              0
# secondAgreement             0
# ï»¿certReason               0
# lcDisposition               0
# lcDispositionDirection      0
# declarationUncon            0
# caseDisposition             0
# caseDispositionUnusual      0
# partyWinning                0
# precedentAlteration         0
# voteUnclear                 0
# issue                       0
# issueArea                   0
# decisionDirection           0
# decisionDirectionDissent    0
# authorityDecision1          0
# authorityDecision2          0
# lawType                     0
# lawSupp                     0
# lawMinor                    0
# majOpinWriter               0
# majOpinAssigner             0
# splitVote                   0
# majVotes                    0
# minVotes                    0
# justice                     0
# justiceName                 0
# vote                        0
# opinion                     0
# direction                   0
# majority                    0
# partyOfPresident            0
# partyOfAppointing           0
# partyOfSenate               0
# dtype: int64

# %%
sc = sc.fillna(0)

# %%
# Drop all outcome variables

sc = sc.drop(['decisionDirection', 'direction','majVotes','minVotes','majority','decisionType','declarationUncon',
              'caseDispositionUnusual','precedentAlteration','voteUnclear','majOpinWriter','majOpinAssigner',
              'splitVote','vote','opinion','majority','firstAgreement','secondAgreement','caseDisposition',
              'dateDecision','dateArgument'], axis=1)

# %%
sc.shape
# Out:
# (120558, 40)

# %%
# Split the dataframe into train and test sets 

from sklearn.model_selection import train_test_split

train, test = train_test_split(sc, train_size=0.9, test_size=0.10, 
                              stratify=sc['partyWinning'], random_state=42)

# %%
train, val = train_test_split(train, train_size=0.85, test_size=0.15, 
                              stratify=train['partyWinning'], random_state=42)

# %%
train.shape, val.shape, test.shape
# Out:
# ((92226, 40), (16276, 40), (12056, 40))

# %%
# Define target feature

target = 'partyWinning'

X_train = train.drop(columns=target)
y_train = train[target]
X_val = val.drop(columns=target)
y_val = val[target]
X_test = test

# %%
import numpy as np
import category_encoders as ce
from sklearn.preprocessing import RobustScaler
from sklearn.impute import SimpleImputer

# %%
### fit_transfom on train, transform on val
from xgboost import XGBClassifier

encoder = ce.OrdinalEncoder()
X_train_encoded = encoder.fit_transform(X_train)
X_val_encoded = encoder.transform(X_val)

model = XGBClassifier(
    n_estimators=1000,  # <= 1000 trees, depends on early stopping
    max_depth=7,        # try deeper trees because of high cardinality categoricals
    learning_rate=0.5,  # try higher learning rate
    n_jobs=-1
)

eval_set = [(X_train_encoded, y_train), 
            (X_val_encoded, y_val)]

model.fit(X_train_encoded, y_train, 
          eval_set=eval_set,
          eval_metric='merror', 
          early_stopping_rounds=50) # Stop if the score hasn't improved in 50 rounds
# Out:
# [0]	validation_0-merror:0.303916	validation_1-merror:0.311256
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 50 rounds.
# [1]	validation_0-merror:0.281916	validation_1-merror:0.289076
# [2]	validation_0-merror:0.263548	validation_1-merror:0.270029
# [3]	validation_0-merror:0.249897	validation_1-merror:0.256881
# [4]	validation_0-merror:0.237157	validation_1-merror:0.245453
# [5]	validation_0-merror:0.218648	validation_1-merror:0.229786
# [6]	validation_0-merror:0.199185	validation_1-merror:0.211293
# [7]	validation_0-merror:0.193373	validation_1-merror:0.205763
# [8]	validation_0-merror:0.186791	validation_1-merror:0.199558
# [9]	validation_0-merror:0.173346	validation_1-merror:0.187823
# [10]	validation_0-merror:0.166016	validation_1-merror:0.180327
# [11]	validation_0-merror:0.160855	validation_1-merror:0.176763
# [12]	validation_0-merror:0.152278	validation_1-merror:0.167056
# [13]	validation_0-merror:0.141099	validation_1-merror:0.153539
# [14]	validation_0-merror:0.139765	validation_1-merror:0.152494
# [15]	validation_0-merror:0.13288	validation_1-merror:0.144937
# [16]	validation_0-merror:0.129508	validation_1-merror:0.14162
# [17]	validation_0-merror:0.124564	validation_1-merror:0.137442
# [18]	validation_0-merror:0.11603	validation_1-merror:0.129516
# [19]	validation_0-merror:0.112474	validation_1-merror:0.126198
# [20]	validation_0-merror:0.108896	validation_1-merror:0.121713
# [21]	validation_0-merror:0.100872	validation_1-merror:0.114217
# [22]	validation_0-merror:0.09737	validation_1-merror:0.109609
# [23]	validation_0-merror:0.091091	validation_1-merror:0.104633
# [24]	validation_0-merror:0.084889	validation_1-merror:0.099226
# [25]	validation_0-merror:0.083686	validation_1-merror:0.097874
# [26]	validation_0-merror:0.082038	validation_1-merror:0.0964
# [27]	validation_0-merror:0.080791	validation_1-merror:0.0964
# [28]	validation_0-merror:0.079565	validation_1-merror:0.094618
# [29]	validation_0-merror:0.078167	validation_1-merror:0.091853
# [30]	validation_0-merror:0.078785	validation_1-merror:0.09216
# [31]	validation_0-merror:0.075022	validation_1-merror:0.087245
# [32]	validation_0-merror:0.071065	validation_1-merror:0.083067
# [33]	validation_0-merror:0.069232	validation_1-merror:0.081347
# [34]	validation_0-merror:0.067476	validation_1-merror:0.078889
# [35]	validation_0-merror:0.065524	validation_1-merror:0.076923
# [36]	validation_0-merror:0.063485	validation_1-merror:0.075387
# [37]	validation_0-merror:0.062683	validation_1-merror:0.074281
# [38]	validation_0-merror:0.060157	validation_1-merror:0.071455
# [39]	validation_0-merror:0.057424	validation_1-merror:0.069059
# [40]	validation_0-merror:0.053738	validation_1-merror:0.064635
# [41]	validation_0-merror:0.05145	validation_1-merror:0.062362
# [42]	validation_0-merror:0.050029	validation_1-merror:0.060887
# [43]	validation_0-merror:0.045703	validation_1-merror:0.056279
# [44]	validation_0-merror:0.042548	validation_1-merror:0.053514
# [45]	validation_0-merror:0.040433	validation_1-merror:0.049705
# [46]	validation_0-merror:0.039219	validation_1-merror:0.048476
# [47]	validation_0-merror:0.038601	validation_1-merror:0.048292
# [48]	validation_0-merror:0.037929	validation_1-merror:0.047739
# [49]	validation_0-merror:0.036562	validation_1-merror:0.046572
# [50]	validation_0-merror:0.034546	validation_1-merror:0.04436
# [51]	validation_0-merror:0.033732	validation_1-merror:0.042332
# [52]	validation_0-merror:0.031282	validation_1-merror:0.039137
# [53]	validation_0-merror:0.030761	validation_1-merror:0.039014
# [54]	validation_0-merror:0.029092	validation_1-merror:0.037294
# [55]	validation_0-merror:0.026825	validation_1-merror:0.034898
# [56]	validation_0-merror:0.025231	validation_1-merror:0.032748
# [57]	validation_0-merror:0.024765	validation_1-merror:0.032256
# [58]	validation_0-merror:0.02418	validation_1-merror:0.031089
# [59]	validation_0-merror:0.022597	validation_1-merror:0.029184
# [60]	validation_0-merror:0.021111	validation_1-merror:0.02771
# [61]	validation_0-merror:0.020515	validation_1-merror:0.026726
# [62]	validation_0-merror:0.02045	validation_1-merror:0.026665
# [63]	validation_0-merror:0.019756	validation_1-merror:0.026235
# [64]	validation_0-merror:0.018205	validation_1-merror:0.024515
# [65]	validation_0-merror:0.017598	validation_1-merror:0.023163
# [66]	validation_0-merror:0.016427	validation_1-merror:0.022487
# [67]	validation_0-merror:0.015972	validation_1-merror:0.02175
# [68]	validation_0-merror:0.013152	validation_1-merror:0.018801
# [69]	validation_0-merror:0.011797	validation_1-merror:0.016159
# [70]	validation_0-merror:0.011624	validation_1-merror:0.015729
# [71]	validation_0-merror:0.010854	validation_1-merror:0.0145
# [72]	validation_0-merror:0.010702	validation_1-merror:0.014377
# [73]	validation_0-merror:0.010041	validation_1-merror:0.013885
# [74]	validation_0-merror:0.00991	validation_1-merror:0.01364
# [75]	validation_0-merror:0.009856	validation_1-merror:0.013517
# [76]	validation_0-merror:0.009661	validation_1-merror:0.012964
# [77]	validation_0-merror:0.009423	validation_1-merror:0.012841
# [78]	validation_0-merror:0.008176	validation_1-merror:0.011489
# [79]	validation_0-merror:0.008045	validation_1-merror:0.011489
# [80]	validation_0-merror:0.007492	validation_1-merror:0.011121
# [81]	validation_0-merror:0.005714	validation_1-merror:0.008847
# [82]	validation_0-merror:0.005573	validation_1-merror:0.008417
# [83]	validation_0-merror:0.005248	validation_1-merror:0.007741
# [84]	validation_0-merror:0.005053	validation_1-merror:0.007803
# [85]	validation_0-merror:0.00463	validation_1-merror:0.007066
# [86]	validation_0-merror:0.004359	validation_1-merror:0.006636
# [87]	validation_0-merror:0.004077	validation_1-merror:0.006083
# [88]	validation_0-merror:0.004077	validation_1-merror:0.006083
# [89]	validation_0-merror:0.003969	validation_1-merror:0.005898
# [90]	validation_0-merror:0.003817	validation_1-merror:0.005652
# [91]	validation_0-merror:0.003513	validation_1-merror:0.005468
# [92]	validation_0-merror:0.003264	validation_1-merror:0.0051
# [93]	validation_0-merror:0.002993	validation_1-merror:0.004362
# [94]	validation_0-merror:0.002776	validation_1-merror:0.004055
# [95]	validation_0-merror:0.002743	validation_1-merror:0.003809
# [96]	validation_0-merror:0.002288	validation_1-merror:0.003195
# [97]	validation_0-merror:0.002201	validation_1-merror:0.003195
# [98]	validation_0-merror:0.002169	validation_1-merror:0.003195
# [99]	validation_0-merror:0.002169	validation_1-merror:0.003195
# [100]	validation_0-merror:0.001746	validation_1-merror:0.002642
# [101]	validation_0-merror:0.001583	validation_1-merror:0.002519
# [102]	validation_0-merror:0.001084	validation_1-merror:0.001905
# [103]	validation_0-merror:0.001019	validation_1-merror:0.001782
# [104]	validation_0-merror:0.000792	validation_1-merror:0.001536
# [105]	validation_0-merror:0.000813	validation_1-merror:0.001536
# [106]	validation_0-merror:0.000759	validation_1-merror:0.001352
# [107]	validation_0-merror:0.000759	validation_1-merror:0.001352
# [108]	validation_0-merror:0.000683	validation_1-merror:0.00129
# [109]	validation_0-merror:0.000683	validation_1-merror:0.00129
# [110]	validation_0-merror:0.000618	validation_1-merror:0.001229
# [111]	validation_0-merror:0.000618	validation_1-merror:0.001229
# [112]	validation_0-merror:0.000683	validation_1-merror:0.00129
# [113]	validation_0-merror:0.000683	validation_1-merror:0.00129
# [114]	validation_0-merror:0.000401	validation_1-merror:0.00086
# [115]	validation_0-merror:0.00039	validation_1-merror:0.000922
# [116]	validation_0-merror:0.000336	validation_1-merror:0.000676
# [117]	validation_0-merror:0.000347	validation_1-merror:0.000676
# [118]	validation_0-merror:0.000347	validation_1-merror:0.000676
# [119]	validation_0-merror:0.000293	validation_1-merror:0.000553
# [120]	validation_0-merror:0.000249	validation_1-merror:0.000307
# [121]	validation_0-merror:0.000249	validation_1-merror:0.000307
# [122]	validation_0-merror:0.000249	validation_1-merror:0.000307
# [123]	validation_0-merror:0.000249	validation_1-merror:0.000307
# [124]	validation_0-merror:0.000249	validation_1-merror:0.000307
# [125]	validation_0-merror:0.000249	validation_1-merror:0.000307
# [126]	validation_0-merror:0.000249	validation_1-merror:0.000307
# [127]	validation_0-merror:0.000249	validation_1-merror:0.000307
# [128]	validation_0-merror:0.000184	validation_1-merror:0.000184
# [129]	validation_0-merror:0.000184	validation_1-merror:0.000184
# [130]	validation_0-merror:0.000184	validation_1-merror:0.000184
# [131]	validation_0-merror:0.000119	validation_1-merror:0.000123
# [132]	validation_0-merror:0.000119	validation_1-merror:0.000123
# [133]	validation_0-merror:5.4e-05	validation_1-merror:0.000123
# [134]	validation_0-merror:5.4e-05	validation_1-merror:0.000123
# [135]	validation_0-merror:5.4e-05	validation_1-merror:0.000123
# [136]	validation_0-merror:5.4e-05	validation_1-merror:0.000123
# [137]	validation_0-merror:5.4e-05	validation_1-merror:0.000123
# [138]	validation_0-merror:5.4e-05	validation_1-merror:0.000123
# [139]	validation_0-merror:5.4e-05	validation_1-merror:0.000123
# [140]	validation_0-merror:5.4e-05	validation_1-merror:0.000123
# [141]	validation_0-merror:0	validation_1-merror:0
# [142]	validation_0-merror:0	validation_1-merror:0
# [143]	validation_0-merror:0	validation_1-merror:0
# [144]	validation_0-merror:0	validation_1-merror:0
# [145]	validation_0-merror:0	validation_1-merror:0
# [146]	validation_0-merror:0	validation_1-merror:0
# [147]	validation_0-merror:0	validation_1-merror:0
# [148]	validation_0-merror:0	validation_1-merror:0
# [149]	validation_0-merror:0	validation_1-merror:0
# [150]	validation_0-merror:0	validation_1-merror:0
# [151]	validation_0-merror:0	validation_1-merror:0
# [152]	validation_0-merror:0	validation_1-merror:0
# [153]	validation_0-merror:0	validation_1-merror:0
# [154]	validation_0-merror:0	validation_1-merror:0
# [155]	validation_0-merror:0	validation_1-merror:0
# [156]	validation_0-merror:0	validation_1-merror:0
# [157]	validation_0-merror:0	validation_1-merror:0
# [158]	validation_0-merror:0	validation_1-merror:0
# [159]	validation_0-merror:0	validation_1-merror:0
# [160]	validation_0-merror:0	validation_1-merror:0
# [161]	validation_0-merror:0	validation_1-merror:0
# [162]	validation_0-merror:0	validation_1-merror:0
# [163]	validation_0-merror:0	validation_1-merror:0
# [164]	validation_0-merror:0	validation_1-merror:0
# [165]	validation_0-merror:0	validation_1-merror:0
# [166]	validation_0-merror:0	validation_1-merror:0
# [167]	validation_0-merror:0	validation_1-merror:0
# [168]	validation_0-merror:0	validation_1-merror:0
# [169]	validation_0-merror:0	validation_1-merror:0
# [170]	validation_0-merror:0	validation_1-merror:0
# [171]	validation_0-merror:0	validation_1-merror:0
# [172]	validation_0-merror:0	validation_1-merror:0
# [173]	validation_0-merror:0	validation_1-merror:0
# [174]	validation_0-merror:0	validation_1-merror:0
# [175]	validation_0-merror:0	validation_1-merror:0
# [176]	validation_0-merror:0	validation_1-merror:0
# [177]	validation_0-merror:0	validation_1-merror:0
# [178]	validation_0-merror:0	validation_1-merror:0
# [179]	validation_0-merror:0	validation_1-merror:0
# [180]	validation_0-merror:0	validation_1-merror:0
# [181]	validation_0-merror:0	validation_1-merror:0
# [182]	validation_0-merror:0	validation_1-merror:0
# [183]	validation_0-merror:0	validation_1-merror:0
# [184]	validation_0-merror:0	validation_1-merror:0
# [185]	validation_0-merror:0	validation_1-merror:0
# [186]	validation_0-merror:0	validation_1-merror:0
# [187]	validation_0-merror:0	validation_1-merror:0
# [188]	validation_0-merror:0	validation_1-merror:0
# [189]	validation_0-merror:0	validation_1-merror:0
# [190]	validation_0-merror:0	validation_1-merror:0
# [191]	validation_0-merror:0	validation_1-merror:0
# Stopping. Best iteration:
# [141]	validation_0-merror:0	validation_1-merror:0
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.5, max_delta_step=0, max_depth=7,
#               min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#               nthread=None, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
results = model.evals_result()
train_error = results['validation_0']['merror']
val_error = results['validation_1']['merror']
epoch = range(1, len(train_error)+1)
plt.plot(epoch, train_error, label='Train')
plt.plot(epoch, val_error, label='Validation')
plt.ylabel('Classification Error')
plt.xlabel('Model Complexity (n_estimators)')
plt.ylim((0.18, 0.22)) # Zoom in
plt.legend();

# %%
1 - 0.18131
# Out:
# 0.81869

# %%
def encoder(df):
  target = 'partyWinning'
  if target in df.columns:
    df_features = df.drop(columns=[target])
  else:
    df_features = df
  numeric_features = df_features.select_dtypes(include='number')
  categorical = df_features.select_dtypes(exclude='number').nunique()
  cat_features = categorical[categorical <= 3].index.tolist()
  high_cardinality_features = pd.DataFrame(categorical[categorical > 3])
  df_high = df[high_cardinality_features.T.columns]
  one_hot_encode = ce.OneHotEncoder(use_cat_names=True)
  one_hot_encode.fit(df[cat_features])
  low_cardinality_features = one_hot_encode.transform(df[cat_features])
  df1 = numeric_features.join(low_cardinality_features, how='outer')
  df2 = df1.join(df_high, how='outer')


  return df2

# %%
X_train = encoder(train)

X_train.head()
# Out:
#         threeJudgeFdc_0.0  threeJudgeFdc_1.0  threeJudgeFdc_nan  \
# 7562                    1                  0                  0
# 34366                   1                  0                  0
# 107518                  1                  0                  0
# 30628                   1                  0                  0
# 50527                   1                  0                  0
#
#         lcDisagreement_1.0  lcDisagreement_0.0  lcDisagreement_nan  \
# 7562                     1                   0                   0
# 34366                    0                   1                   0
# 107518                   1                   0                   0
# 30628                    0                   1                   0
# 50527                    0                   1                   0
#
#         decisionDirectionDissent_0.0  decisionDirectionDissent_nan  \
# 7562                               1                             0
# 34366                              1                             0
# 107518                             1                             0
# 30628                              1                             0
# 50527                              1                             0
#
#         decisionDirectionDissent_1.0  partyOfPresident_Democrat  \
# 7562                               0                          1
# 34366                              0                          1
# 107518                             0                          0
# 30628                              0                          1
# 50527                              0                          0
#
#         partyOfPresident_Republican  partyOfAppointing_Democrat  \
# 7562                              0                           1
# 34366                             0                           0
# 107518                            1                           0
# 30628                             0                           0
# 50527                             1                           0
#
#         partyOfAppointing_Republican  partyOfSenate_Democrat  \
# 7562                               0                       1
# 34366                              1                       1
# 107518                             1                       0
# 30628                              1                       1
# 50527                              1                       1
#
#         partyOfSenate_Republican    caseId     docketId                voteId  \
# 7562                           0  1949-068  1949-068-01  1949-068-01-02-01-03
# 34366                          0  1965-003  1965-003-01  1965-003-01-01-01-09
# 107518                         1  2004-004  2004-004-01  2004-004-01-01-01-04
# 30628                          0  1963-018  1963-018-01  1963-018-01-01-01-05
# 50527                          0  1972-092  1972-092-01  1972-092-01-01-01-07
#
#                   ledCite  term naturalCourt      chief   docket  \
# 7562     94 L. Ed. 2d 884  1949         1303     Vinson       99
# 34366     15 L. Ed. 2d 21  1965         1409     Warren      919
# 107518  160 L. Ed. 2d 389  2004         1607  Rehnquist   03-377
# 30628    11 L. Ed. 2d 159  1963         1408     Warren       50
# 50527    36 L. Ed. 2d 208  1972         1504     Burger  71-6193
#
#                                                  caseName dateRearg  \
# 7562                               UNITED STATES v. BRYAN       nan
# 34366   GONDECK v. PAN AMERICAN WORLD AIRWAYS, INC., e...       nan
# 107518      KOONS BUICK PONTIAC GMC, INC. v. BRADLEY NIGH       nan
# 30628                            GOTTHILF v. SILLS et al.       nan
# 50527                       BROWN et al. v. UNITED STATES       nan
#
#        petitioner petitionerState respondent respondentState jurisdiction  \
# 7562         27.0             nan      254.0             nan            1
# 34366         8.0            60.0      104.0             nan            6
# 107518      125.0             nan      123.0             nan            1
# 30628       138.0             nan      135.0             nan            1
# 50527       100.0             nan       27.0             nan            1
#
#        adminAction adminActionState caseOrigin caseOriginState caseSource  \
# 7562           nan              nan       55.0            10.0       32.0
# 34366         31.0              nan       58.0             nan       25.0
# 107518         nan              nan      126.0             nan       24.0
# 30628          nan              nan      302.0            37.0      301.0
# 50527          nan              nan       73.0             nan       26.0
#
#        caseSourceState ï»¿certReason lcDisposition lcDispositionDirection  \
# 7562               nan          10.0           3.0                    2.0
# 34366              nan           1.0           2.0                    1.0
# 107518             nan           2.0           2.0                    2.0
# 30628             37.0          12.0           2.0                    1.0
# 50527              nan          12.0           2.0                    1.0
#
#           issue issueArea authorityDecision1 authorityDecision2 lawType  \
# 7562    10090.0       1.0                4.0                nan     6.0
# 34366   80050.0       8.0                3.0                nan     nan
# 107518  80170.0       8.0                4.0                nan     3.0
# 30628   90350.0       9.0                4.0                nan     6.0
# 50527   10050.0       1.0                1.0                nan     2.0
#
#        lawSupp           lawMinor justice justiceName
# 7562     600.0  18 U.S.C. Ã 3486      86    HHBurton
# 34366      nan                nan      97     AFortas
# 107518   373.0                nan     105     AScalia
# 30628    600.0  28 U.S.C. Ã 1257      92   WJBrennan
# 50527    205.0                nan     100  HABlackmun

# %%
X_val = encoder(val)

X_val.head()
# Out:
#         threeJudgeFdc_0.0  threeJudgeFdc_1.0  threeJudgeFdc_nan  \
# 6134                    1                  0                  0
# 116891                  1                  0                  0
# 21001                   1                  0                  0
# 74554                   1                  0                  0
# 110784                  1                  0                  0
#
#         lcDisagreement_0.0  lcDisagreement_1.0  lcDisagreement_nan  \
# 6134                     1                   0                   0
# 116891                   1                   0                   0
# 21001                    1                   0                   0
# 74554                    1                   0                   0
# 110784                   0                   1                   0
#
#         decisionDirectionDissent_0.0  decisionDirectionDissent_1.0  \
# 6134                               1                             0
# 116891                             1                             0
# 21001                              1                             0
# 74554                              1                             0
# 110784                             1                             0
#
#         decisionDirectionDissent_nan  partyOfPresident_Democrat  \
# 6134                               0                          1
# 116891                             0                          1
# 21001                              0                          0
# 74554                              0                          0
# 110784                             0                          0
#
#         partyOfPresident_Republican  partyOfAppointing_Democrat  \
# 6134                              0                           1
# 116891                            0                           0
# 21001                             1                           1
# 74554                             1                           0
# 110784                            1                           0
#
#         partyOfAppointing_Republican  partyOfSenate_Democrat  \
# 6134                               0                       1
# 116891                             1                       1
# 21001                              0                       1
# 74554                              1                       0
# 110784                             1                       1
#
#         partyOfSenate_Republican    caseId     docketId                voteId  \
# 6134                           0  1948-101  1948-101-01  1948-101-01-04-01-06
# 116891                         0  2014-022  2014-022-01  2014-022-01-02-01-03
# 21001                          0  1958-016  1958-016-02  1958-016-02-01-01-02
# 74554                          1  1982-144  1982-144-03  1982-144-03-01-01-01
# 110784                         0  2007-047  2007-047-01  2007-047-01-01-01-05
#
#                   ledCite  term naturalCourt    chief   docket  \
# 6134    93 L. Ed. 2d 1528  1948         1301   Vinson      442
# 116891  191 L. Ed. 2d 186  2014         1704  Roberts  13-1041
# 21001     3 L. Ed. 2d 153  1958         1406   Warren       25
# 74554    77 L. Ed. 2d 668  1982         1507   Burger  81-2042
# 110784  170 L. Ed. 2d 975  2007         1702  Roberts   07-474
#
#                                                  caseName dateRearg  \
# 6134    COHEN, EXECUTRIX, ET AL. v. BENEFICIAL INDUSTR...       nan
# 116891                    PEREZ v. MORTGAGE BANKERS ASS'N       nan
# 21001   FEDERAL POWER COMMISSION v. MEMPHIS LIGHT, GAS...       nan
# 74554            MICHIGAN v. MID-LOUISIANA GAS CO. et al.       nan
# 110784  ANUP ENGQUIST v. OREGON DEPARTMENT OF AGRICULT...       nan
#
#        petitioner petitionerState respondent respondentState jurisdiction  \
# 6134        237.0             nan      185.0             nan            1
# 116891      371.0             nan      113.0             nan            1
# 21001       352.0             nan      148.0             nan            1
# 74554        28.0            27.0      209.0             nan            1
# 110784        8.0            43.0        7.0            43.0            1
#
#        adminAction adminActionState caseOrigin caseOriginState caseSource  \
# 6134           nan              nan       92.0            35.0       23.0
# 116891        71.0              nan       55.0             nan       32.0
# 21001         52.0              nan       32.0             nan       32.0
# 74554         44.0              nan       25.0             nan       25.0
# 110784         nan              nan      108.0             nan       29.0
#
#        caseSourceState ï»¿certReason lcDisposition lcDispositionDirection  \
# 6134               nan          12.0           3.0                    1.0
# 116891             nan          12.0           3.0                    2.0
# 21001              nan          11.0           3.0                    2.0
# 74554              nan          12.0           3.0                    1.0
# 110784             nan           2.0           3.0                    1.0
#
#            issue issueArea authorityDecision1 authorityDecision2 lawType  \
# 6134    100130.0      10.0                2.0                nan     2.0
# 116891   90120.0       9.0                4.0                7.0     3.0
# 21001    80310.0       8.0                4.0                nan     3.0
# 74554    90120.0       9.0                5.0                4.0     3.0
# 110784   20060.0       2.0                2.0                nan     2.0
#
#        lawSupp lawMinor justice justiceName
# 6134     230.0      nan      78     HLBlack
# 116891   305.0      nan     106   AMKennedy
# 21001    355.0      nan      78     HLBlack
# 74554    355.0      nan      98   TMarshall
# 110784   231.0      nan     107    DHSouter

# %%
X_train.shape
# Out:
# (92226, 48)

# %%
X_val.shape
# Out:
# (16276, 48)

# %%
# set(X_train.columns).symmetric_difference(set(X_val.columns))

# %%
# set(X_train.columns).intersection(set(X_val.columns))

# %%
import category_encoders as ce
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline

pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='median'), 
    RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
)

# Fit on train, score on val
pipeline.fit(X_train, y_train)
print('Validation Accuracy', pipeline.score(X_val, y_val))
# Out:
# Validation Accuracy 0.9257802899975424

# %%
# Get feature importances
rf = pipeline.named_steps['randomforestclassifier']
importances = pd.Series(rf.feature_importances_, X_train.columns)

# Plot feature importances
# %matplotlib inline
import matplotlib.pyplot as plt

n = 20
plt.figure(figsize=(10,n/2))
plt.title(f'Top {n} features')
importances.sort_values()[-n:].plot.barh(color='grey');

# %%
# # Try permutation importance for feature importance

# feature = 'decisionDirection'
# X_val_permuted = X_val.copy()
# X_val_permuted[feature] = np.random.permutation(X_val[feature])

# score_with = pipeline.score(X_val, y_val)
# score_permuted = pipeline.score(X_val_permuted, y_val) 

# print(f'Validation Accuracy with {feature}: {score_with}')
# print(f'Validation Accuracy with {feature} permuted: {score_permuted}')
# print(f'Permutation Importance: {score_with - score_permuted}')

# %%
feature = 'justiceName'
X_val_permuted = X_val.copy()
X_val_permuted[feature] = np.random.permutation(X_val[feature])

score_with = pipeline.score(X_val, y_val)
score_permuted = pipeline.score(X_val_permuted, y_val) 

print(f'Validation Accuracy with {feature}: {score_with}')
print(f'Validation Accuracy with {feature} permuted: {score_permuted}')
print(f'Permutation Importance: {score_with - score_permuted}')
# Out:
# Validation Accuracy with justiceName: 0.9257802899975424
# Validation Accuracy with justiceName permuted: 0.9251658884246744
# Permutation Importance: 0.0006144015728679619

# %%
feature = 'petitioner'
X_val_permuted = X_val.copy()
X_val_permuted[feature] = np.random.permutation(X_val[feature])

score_with = pipeline.score(X_val, y_val)
score_permuted = pipeline.score(X_val_permuted, y_val) 

print(f'Validation Accuracy with {feature}: {score_with}')
print(f'Validation Accuracy with {feature} permuted: {score_permuted}')
print(f'Permutation Importance: {score_with - score_permuted}')
# Out:
# Validation Accuracy with petitioner: 0.9257802899975424
# Validation Accuracy with petitioner permuted: 0.865507495699189
# Permutation Importance: 0.060272794298353416

# %%
feature = 'respondent'
X_val_permuted = X_val.copy()
X_val_permuted[feature] = np.random.permutation(X_val[feature])

score_with = pipeline.score(X_val, y_val)
score_permuted = pipeline.score(X_val_permuted, y_val) 

print(f'Validation Accuracy with {feature}: {score_with}')
print(f'Validation Accuracy with {feature} permuted: {score_permuted}')
print(f'Permutation Importance: {score_with - score_permuted}')
# Out:
# Validation Accuracy with respondent: 0.9257802899975424
# Validation Accuracy with respondent permuted: 0.8218849840255591
# Permutation Importance: 0.10389530597198327

# %%
feature = 'term'
X_val_permuted = X_val.copy()
X_val_permuted[feature] = np.random.permutation(X_val[feature])

score_with = pipeline.score(X_val, y_val)
score_permuted = pipeline.score(X_val_permuted, y_val) 

print(f'Validation Accuracy with {feature}: {score_with}')
print(f'Validation Accuracy with {feature} permuted: {score_permuted}')
print(f'Permutation Importance: {score_with - score_permuted}')
# Out:
# Validation Accuracy with term: 0.9257802899975424
# Validation Accuracy with term permuted: 0.8764438436962398
# Permutation Importance: 0.04933644630130252

# %%
feature = 'lawSupp'
X_val_permuted = X_val.copy()
X_val_permuted[feature] = np.random.permutation(X_val[feature])

score_with = pipeline.score(X_val, y_val)
score_permuted = pipeline.score(X_val_permuted, y_val) 

print(f'Validation Accuracy with {feature}: {score_with}')
print(f'Validation Accuracy with {feature} permuted: {score_permuted}')
print(f'Permutation Importance: {score_with - score_permuted}')
# Out:
# Validation Accuracy with lawSupp: 0.9257802899975424
# Validation Accuracy with lawSupp permuted: 0.8713443106414352
# Permutation Importance: 0.05443597935610711

# %%
feature = 'issue'
X_val_permuted = X_val.copy()
X_val_permuted[feature] = np.random.permutation(X_val[feature])

score_with = pipeline.score(X_val, y_val)
score_permuted = pipeline.score(X_val_permuted, y_val) 

print(f'Validation Accuracy with {feature}: {score_with}')
print(f'Validation Accuracy with {feature} permuted: {score_permuted}')
print(f'Permutation Importance: {score_with - score_permuted}')
# Out:
# Validation Accuracy with issue: 0.9257802899975424
# Validation Accuracy with issue permuted: 0.8718972720570165
# Permutation Importance: 0.05388301794052586

# %%
feature = 'issueArea'
X_val_permuted = X_val.copy()
X_val_permuted[feature] = np.random.permutation(X_val[feature])

score_with = pipeline.score(X_val, y_val)
score_permuted = pipeline.score(X_val_permuted, y_val) 

print(f'Validation Accuracy with {feature}: {score_with}')
print(f'Validation Accuracy with {feature} permuted: {score_permuted}')
print(f'Permutation Importance: {score_with - score_permuted}')
# Out:
# Validation Accuracy with issueArea: 0.9257802899975424
# Validation Accuracy with issueArea permuted: 0.8927254853772426
# Permutation Importance: 0.03305480462029975

# %%
# Use eli5 library

transformers = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='median')
)

X_train_transformed = transformers.fit_transform(X_train)
X_val_transformed = transformers.transform(X_val)

model = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
model.fit(X_train_transformed, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
import eli5
from eli5.sklearn import PermutationImportance

permuter = PermutationImportance(
    model,
    scoring='accuracy',
    n_iter=5,  
    random_state=42  
)

permuter.fit(X_val_transformed, y_val)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)
# PermutationImportance(cv='prefit',
#                       estimator=RandomForestClassifier(bootstrap=True,
#                                                        ccp_alpha=0.0,
#                                                        class_weight=None,
#                                                        criterion='gini',
#                                                        max_depth=None,
#                                                        max_features='auto',
#                                                        max_leaf_nodes=None,
#                                                        max_samples=None,
#                                                        min_impurity_decrease=0.0,
#                                                        min_impurity_split=None,
#                                                        min_samples_leaf=1,
#                                                        min_samples_split=2,
#                                                        min_weight_fraction_leaf=0.0,
#                                                        n_estimators=100,
#                                                        n_jobs=-1,
#                                                        oob_score=False,
#                                                        random_state=42,
#                                                        verbose=0,
#                                                        warm_start=False),
#                       n_iter=5, random_state=42, refit=True,
#                       scoring='accuracy')

# %%
feature_names = X_val.columns.tolist()
pd.Series(permuter.feature_importances_, feature_names).sort_values(
    ascending=False)
# Out:
# respondent                      0.102617
# ï»¿certReason                   0.087798
# petitioner                      0.060826
# issue                           0.056918
# lawSupp                         0.054559
# term                            0.048599
# naturalCourt                    0.048550
# chief                           0.047247
# caseSource                      0.045527
# caseOrigin                      0.043426
# ledCite                         0.035832
# lcDisposition                   0.034333
# docket                          0.034112
# lawType                         0.034075
# caseId                          0.033276
# issueArea                       0.032059
# authorityDecision1              0.029663
# caseName                        0.028373
# docketId                        0.026653
# respondentState                 0.021996
# adminAction                     0.020029
# lcDispositionDirection          0.016589
# caseOriginState                 0.015827
# caseSourceState                 0.012448
# authorityDecision2              0.011133
# partyOfPresident_Republican     0.010678
# petitionerState                 0.010482
# lawMinor                        0.008552
# partyOfSenate_Republican        0.008196
# jurisdiction                    0.008147
# partyOfPresident_Democrat       0.008012
# partyOfSenate_Democrat          0.007213
# adminActionState                0.003305
# dateRearg                       0.002802
# decisionDirectionDissent_0.0    0.002040
# threeJudgeFdc_1.0               0.001241
# threeJudgeFdc_0.0               0.001155
# justiceName                     0.000442
# partyOfAppointing_Republican    0.000184
# partyOfAppointing_Democrat      0.000147
# voteId                          0.000000
# lcDisagreement_nan              0.000000
# threeJudgeFdc_nan               0.000000
# decisionDirectionDissent_1.0   -0.000012
# justice                        -0.000123
# decisionDirectionDissent_nan   -0.000283
# lcDisagreement_0.0             -0.019169
# lcDisagreement_1.0             -0.020386
# dtype: float64

# %%
eli5.show_weights(
    permuter,
    top=None,
    feature_names=feature_names
)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1026
#
#                     &plusmn; 0.0019
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 respondent
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 82.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0878
#
#                     &plusmn; 0.0033
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ï»¿certReason
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.13%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0608
#
#                     &plusmn; 0.0034
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 petitioner
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.76%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0569
#
#                     &plusmn; 0.0022
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 issue
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.15%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0546
#
#                     &plusmn; 0.0019
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lawSupp
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.15%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0486
#
#                     &plusmn; 0.0018
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 term
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.16%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0486
#
#                     &plusmn; 0.0021
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 naturalCourt
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0472
#
#                     &plusmn; 0.0018
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 chief
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.68%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0455
#
#                     &plusmn; 0.0037
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 caseSource
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.05%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0434
#
#                     &plusmn; 0.0019
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 caseOrigin
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.42%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0358
#
#                     &plusmn; 0.0021
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ledCite
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.71%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0343
#
#                     &plusmn; 0.0009
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lcDisposition
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.75%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0341
#
#                     &plusmn; 0.0021
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 docket
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.76%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0341
#
#                     &plusmn; 0.0020
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lawType
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.91%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0333
#
#                     &plusmn; 0.0029
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 caseId
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.14%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0321
#
#                     &plusmn; 0.0011
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 issueArea
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.61%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0297
#
#                     &plusmn; 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 authorityDecision1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.87%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0284
#
#                     &plusmn; 0.0019

# %%
minimum_importance = 0.03
mask = (permuter.feature_importances_ - permuter.feature_importances_std_) > minimum_importance
mask
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#         True,  True,  True,  True,  True, False, False,  True, False,
#         True, False, False, False, False,  True, False,  True, False,
#         True,  True, False,  True,  True, False, False,  True,  True,
#        False, False, False])

# %%
features = X_train.columns[mask]
X_train_selected = X_train[features]
X_train_selected.shape
# Out:
# (92226, 16)

# %%
X_val_selected = X_val[features]

pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='median'), 
    RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
)

# Fit on train, score on val
pipeline.fit(X_train_selected, y_train)
print('Validation Accuracy', pipeline.score(X_val_selected, y_val))
# Out:
# Validation Accuracy 1.0

# %%
X_train_selected.columns
# Out:
# Index(['caseId', 'ledCite', 'term', 'naturalCourt', 'chief', 'docket',
#        'petitioner', 'respondent', 'caseOrigin', 'caseSource', 'ï»¿certReason',
#        'lcDisposition', 'issue', 'issueArea', 'lawType', 'lawSupp'],
#       dtype='object')

# %%
X_train_selected.head()
# Out:
#           caseId            ledCite  term naturalCourt      chief   docket  \
# 7562    1949-068   94 L. Ed. 2d 884  1949         1303     Vinson       99
# 34366   1965-003    15 L. Ed. 2d 21  1965         1409     Warren      919
# 107518  2004-004  160 L. Ed. 2d 389  2004         1607  Rehnquist   03-377
# 30628   1963-018   11 L. Ed. 2d 159  1963         1408     Warren       50
# 50527   1972-092   36 L. Ed. 2d 208  1972         1504     Burger  71-6193
#
#        petitioner respondent caseOrigin caseSource ï»¿certReason  \
# 7562         27.0      254.0       55.0       32.0          10.0
# 34366         8.0      104.0       58.0       25.0           1.0
# 107518      125.0      123.0      126.0       24.0           2.0
# 30628       138.0      135.0      302.0      301.0          12.0
# 50527       100.0       27.0       73.0       26.0          12.0
#
#        lcDisposition    issue issueArea lawType lawSupp
# 7562             3.0  10090.0       1.0     6.0   600.0
# 34366            2.0  80050.0       8.0     nan     nan
# 107518           2.0  80170.0       8.0     3.0   373.0
# 30628            2.0  90350.0       9.0     6.0   600.0
# 50527            2.0  10050.0       1.0     2.0   205.0
