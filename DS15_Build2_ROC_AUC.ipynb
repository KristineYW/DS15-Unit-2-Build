# %% [markdown]
# <a href="https://colab.research.google.com/github/KristineYW/DS-Unit-2-Applied-Modeling/blob/master/Kristine_Wang_LS_DS_232_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Your code starts here:

# %%
# Read in csv

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

sc1 = pd.read_csv('https://raw.githubusercontent.com/KristineYW/DS-Unit-2-Applied-Modeling/master/SCDB_2019_01_justiceCentered_LegalProvision_1.csv', encoding = "ISO-8859-1")

sc1.head()
# Out:
#      caseId     docketId                voteId dateDecision  decisionType  \
# 0  1946-001  1946-001-01  1946-001-01-01-01-01     11/18/46             1
# 1  1946-001  1946-001-01  1946-001-01-01-01-02     11/18/46             1
# 2  1946-001  1946-001-01  1946-001-01-01-01-03     11/18/46             1
# 3  1946-001  1946-001-01  1946-001-01-01-01-04     11/18/46             1
# 4  1946-001  1946-001-01  1946-001-01-01-01-05     11/18/46             1
#
#        ledCite  term  naturalCourt   chief docket  ... Unnamed: 47  \
# 0  91 L. Ed. 3  1946          1301  Vinson     24  ...         NaN
# 1  91 L. Ed. 3  1946          1301  Vinson     24  ...         NaN
# 2  91 L. Ed. 3  1946          1301  Vinson     24  ...         NaN
# 3  91 L. Ed. 3  1946          1301  Vinson     24  ...         NaN
# 4  91 L. Ed. 3  1946          1301  Vinson     24  ...         NaN
#
#   Unnamed: 48 Unnamed: 49  Unnamed: 50  Unnamed: 51  Unnamed: 52  Unnamed: 53  \
# 0         NaN         NaN          NaN          NaN          NaN          NaN
# 1         NaN         NaN          NaN          NaN          NaN          NaN
# 2         NaN         NaN          NaN          NaN          NaN          NaN
# 3         NaN         NaN          NaN          NaN          NaN          NaN
# 4         NaN         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 54  firstAgreement  secondAgreement
# 0          NaN             NaN              NaN
# 1          NaN             NaN              NaN
# 2          NaN             NaN              NaN
# 3          NaN             NaN              NaN
# 4          NaN             NaN              NaN
#
# [5 rows x 57 columns]

# %%
sc2 = pd.read_csv('https://raw.githubusercontent.com/KristineYW/DS-Unit-2-Applied-Modeling/master/SCDB_2019_01_justiceCentered_LegalProvision_2.csv', encoding = "ISO-8859-1")

sc2.head()
# Out:
#    ï»¿certReason  lcDisposition  lcDispositionDirection  declarationUncon  \
# 0           11.0            2.0                     1.0               1.0
# 1           11.0            2.0                     1.0               1.0
# 2           11.0            2.0                     1.0               1.0
# 3           11.0            2.0                     1.0               1.0
# 4           11.0            2.0                     1.0               1.0
#
#    caseDisposition  caseDispositionUnusual  partyWinning  precedentAlteration  \
# 0              3.0                     0.0           1.0                  1.0
# 1              3.0                     0.0           1.0                  1.0
# 2              3.0                     0.0           1.0                  1.0
# 3              3.0                     0.0           1.0                  1.0
# 4              3.0                     0.0           1.0                  1.0
#
#    voteUnclear    issue  ...  majOpinAssigner  splitVote  majVotes  minVotes  \
# 0          0.0  80180.0  ...             78.0          1         8         1
# 1          0.0  80180.0  ...             78.0          1         8         1
# 2          0.0  80180.0  ...             78.0          1         8         1
# 3          0.0  80180.0  ...             78.0          1         8         1
# 4          0.0  80180.0  ...             78.0          1         8         1
#
#    justice   justiceName  vote opinion  direction  majority
# 0       86      HHBurton   2.0     1.0        1.0       1.0
# 1       84     RHJackson   1.0     1.0        2.0       2.0
# 2       81     WODouglas   1.0     1.0        2.0       2.0
# 3       80  FFrankfurter   4.0     2.0        2.0       2.0
# 4       79        SFReed   1.0     1.0        2.0       2.0
#
# [5 rows x 29 columns]

# %%
# Join the two large datasets into one dataframe

sc = pd.concat([sc1,sc2], axis=1)

sc.head()
# Out:
#      caseId     docketId                voteId dateDecision  decisionType  \
# 0  1946-001  1946-001-01  1946-001-01-01-01-01     11/18/46             1
# 1  1946-001  1946-001-01  1946-001-01-01-01-02     11/18/46             1
# 2  1946-001  1946-001-01  1946-001-01-01-01-03     11/18/46             1
# 3  1946-001  1946-001-01  1946-001-01-01-01-04     11/18/46             1
# 4  1946-001  1946-001-01  1946-001-01-01-01-05     11/18/46             1
#
#        ledCite  term  naturalCourt   chief docket  ... majOpinAssigner  \
# 0  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 1  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 2  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 3  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 4  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
#
#   splitVote majVotes  minVotes  justice   justiceName  vote  opinion  \
# 0         1        8         1       86      HHBurton   2.0      1.0
# 1         1        8         1       84     RHJackson   1.0      1.0
# 2         1        8         1       81     WODouglas   1.0      1.0
# 3         1        8         1       80  FFrankfurter   4.0      2.0
# 4         1        8         1       79        SFReed   1.0      1.0
#
#    direction  majority
# 0        1.0       1.0
# 1        2.0       2.0
# 2        2.0       2.0
# 3        2.0       2.0
# 4        2.0       2.0
#
# [5 rows x 86 columns]

# %%
sc = sc.drop(['Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 
              'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 
              'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 
              'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 
              'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 
              'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54'], axis=1)

sc.head()
# Out:
#      caseId     docketId                voteId dateDecision  decisionType  \
# 0  1946-001  1946-001-01  1946-001-01-01-01-01     11/18/46             1
# 1  1946-001  1946-001-01  1946-001-01-01-01-02     11/18/46             1
# 2  1946-001  1946-001-01  1946-001-01-01-01-03     11/18/46             1
# 3  1946-001  1946-001-01  1946-001-01-01-01-04     11/18/46             1
# 4  1946-001  1946-001-01  1946-001-01-01-01-05     11/18/46             1
#
#        ledCite  term  naturalCourt   chief docket  ... majOpinAssigner  \
# 0  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 1  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 2  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 3  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
# 4  91 L. Ed. 3  1946          1301  Vinson     24  ...            78.0
#
#   splitVote majVotes  minVotes  justice   justiceName  vote  opinion  \
# 0         1        8         1       86      HHBurton   2.0      1.0
# 1         1        8         1       84     RHJackson   1.0      1.0
# 2         1        8         1       81     WODouglas   1.0      1.0
# 3         1        8         1       80  FFrankfurter   4.0      2.0
# 4         1        8         1       79        SFReed   1.0      1.0
#
#    direction  majority
# 0        1.0       1.0
# 1        2.0       2.0
# 2        2.0       2.0
# 3        2.0       2.0
# 4        2.0       2.0
#
# [5 rows x 57 columns]

# %%
import datetime

# %%
sc['dateDecision'][7]
# Out:
# '11/18/46'

# %%
sc.sample(10)
# Out:
#           caseId     docketId                voteId dateDecision  \
# 88505   1989-016  1989-016-03  1989-016-03-09-01-01      1/10/90
# 79266   1984-168  1984-168-01  1984-168-01-02-01-06       7/2/85
# 57988   1975-125  1975-125-01  1975-125-01-01-01-03      6/14/76
# 111582  2008-043  2008-043-01  2008-043-01-01-01-04       4/6/09
# 99809   1997-040  1997-040-01  1997-040-01-01-01-06       3/9/98
# 56145   1974-134  1974-134-01  1974-134-01-02-01-09      6/24/75
# 44374   1969-074  1969-074-01  1969-074-01-01-01-05      4/20/70
# 61489   1977-017  1977-017-01  1977-017-01-01-01-04     12/12/77
# 73748   1982-091  1982-091-01  1982-091-01-01-01-05      5/31/83
# 49882   1972-039  1972-039-01  1972-039-01-02-01-01      1/16/73
#
#         decisionType            ledCite  term  naturalCourt      chief  \
# 88505              1  107 L. Ed. 2d 603  1989          1603  Rehnquist
# 79266              1   87 L. Ed. 2d 567  1984          1507     Burger
# 57988              1   48 L. Ed. 2d 757  1975          1506     Burger
# 111582             1  173 L. Ed. 2d 443  2008          1702    Roberts
# 99809              1  140 L. Ed. 2d 271  1997          1607  Rehnquist
# 56145              1   45 L. Ed. 2d 223  1974          1504     Burger
# 44374              1   25 L. Ed. 2d 547  1969          1501     Burger
# 61489              1   54 L. Ed. 2d 402  1977          1506     Burger
# 73748              1   76 L. Ed. 2d 312  1982          1507     Burger
# 49882              1    35 L. Ed. 2d 29  1972          1504     Burger
#
#           docket  ... majOpinAssigner splitVote majVotes  minVotes  justice  \
# 88505      88-49  ...           102.0         1        8         1       98
# 79266     84-312  ...            99.0         1        4         3      101
# 57988    74-1471  ...            99.0         1        8         0       92
# 111582  07-10441  ...           103.0         1        5         4      106
# 99809    96-7151  ...           102.0         1        8         1      107
# 56145     74-156  ...            99.0         1        5         4      102
# 44374        369  ...            99.0         1        5         3       98
# 61489     76-906  ...            99.0         1        7         2       95
# 73748    81-2125  ...            99.0         1        9         0      100
# 49882    71-6272  ...            99.0         1        6         3       81
#
#         justiceName  vote  opinion  direction  majority
# 88505     TMarshall   4.0      1.0        2.0       2.0
# 79266      LFPowell   NaN      NaN        NaN       NaN
# 57988     WJBrennan   1.0      1.0        1.0       2.0
# 111582    AMKennedy   1.0      1.0        2.0       2.0
# 99809      DHSouter   1.0      1.0        2.0       2.0
# 56145   WHRehnquist   1.0      1.0        2.0       2.0
# 44374     TMarshall   1.0      1.0        2.0       2.0
# 61489       BRWhite   4.0      2.0        1.0       2.0
# 73748    HABlackmun   1.0      1.0        2.0       2.0
# 49882     WODouglas   2.0      1.0        2.0       1.0
#
# [10 rows x 57 columns]

# %%
# Change dateDecision to datetime data type 


def yearConvert(date):
    year_int = int(date[-2:])
    if year_int > 20:
        edited_str = date[:-2] + '19' + date[-2:]
    else:
        edited_str = date[:-2] + '20' + date[-2:]
    return(pd.to_datetime(edited_str))
sc['dateDecision'] = [yearConvert(i) for i in sc['dateDecision']]
sc['dateDecision'].describe
# Out:
# <bound method NDFrame.describe of 0        1946-11-18
# 1        1946-11-18
# 2        1946-11-18
# 3        1946-11-18
# 4        1946-11-18
#             ...
# 120553   2019-05-28
# 120554   2019-05-28
# 120555   2019-05-28
# 120556   2019-05-28
# 120557   2019-05-28
# Name: dateDecision, Length: 120558, dtype: datetime64[ns]>

# %%
# Introduce new features for senate majority party and presidential party


sc['partyOfPresident'] = np.where((sc['dateDecision'] < '1953-01-19') | ('1961-01-20' < sc['dateDecision']) & (sc['dateDecision'] < '1969-01-19') | 
                                  ('1977-01-20' < sc['dateDecision']) & (sc['dateDecision'] < '1981-01-19') | 
                                  ('1993-01-20' < sc['dateDecision']) & (sc['dateDecision'] < '2001-01-19') | 
                                  ('2009-01-20' < sc['dateDecision']) & (sc['dateDecision'] < '2017-01-20'), 
                                  'Democrat','Republican')

# %%
sc['partyOfAppointing'] = np.where((sc['justiceName'] == 'BRWhite') | (sc['justiceName'] == 'WODouglas') | (sc['justiceName'] == 'Tmarshall') | 
                                (sc['justiceName'] == 'HLBlack') | (sc['justiceName'] == 'TCClark') | (sc['justiceName'] == 'Ffrankfurter') | 
                                (sc['justiceName']== 'RBGinsburg') | (sc['justiceName'] == 'SGBreyer') | (sc['justiceName'] == 'HHBurton') | 
                                (sc['justiceName'] == 'SFReed') | (sc['justiceName'] == 'RHJackson') | (sc['justiceName'] == 'FMVinson') | 
                                (sc['justiceName'] == 'Sminton') | (sc['justiceName'] == 'Ssotomayor') | (sc['justiceName'] == 'Afortas') | 
                                (sc['justiceName'] == 'Ekagan') | (sc['justiceName'] == 'Fmurphy') | (sc['justiceName'] == 'WBRutledge') | 
                                (sc['justiceName'] == 'AJGoldberg'), 'Democrat','Republican' )

# %%
sc.head()
# Out:
#      caseId     docketId                voteId dateDecision  decisionType  \
# 0  1946-001  1946-001-01  1946-001-01-01-01-01   1946-11-18             1
# 1  1946-001  1946-001-01  1946-001-01-01-01-02   1946-11-18             1
# 2  1946-001  1946-001-01  1946-001-01-01-01-03   1946-11-18             1
# 3  1946-001  1946-001-01  1946-001-01-01-01-04   1946-11-18             1
# 4  1946-001  1946-001-01  1946-001-01-01-01-05   1946-11-18             1
#
#        ledCite  term  naturalCourt   chief docket  ... majVotes minVotes  \
# 0  91 L. Ed. 3  1946          1301  Vinson     24  ...        8        1
# 1  91 L. Ed. 3  1946          1301  Vinson     24  ...        8        1
# 2  91 L. Ed. 3  1946          1301  Vinson     24  ...        8        1
# 3  91 L. Ed. 3  1946          1301  Vinson     24  ...        8        1
# 4  91 L. Ed. 3  1946          1301  Vinson     24  ...        8        1
#
#   justice   justiceName  vote  opinion  direction  majority  partyOfPresident  \
# 0      86      HHBurton   2.0      1.0        1.0       1.0          Democrat
# 1      84     RHJackson   1.0      1.0        2.0       2.0          Democrat
# 2      81     WODouglas   1.0      1.0        2.0       2.0          Democrat
# 3      80  FFrankfurter   4.0      2.0        2.0       2.0          Democrat
# 4      79        SFReed   1.0      1.0        2.0       2.0          Democrat
#
#    partyOfAppointing
# 0           Democrat
# 1           Democrat
# 2           Democrat
# 3         Republican
# 4           Democrat
#
# [5 rows x 59 columns]

# %%
sc['partyOfPresident'].value_counts(normalize=True)
# Out:
# Republican    0.551909
# Democrat      0.448091
# Name: partyOfPresident, dtype: float64

# %%
sc['partyOfSenate'] = np.where((sc['dateDecision'] < '1947-01-03') | ('1949-01-03' < sc['dateDecision']) & (sc['dateDecision'] < '1953-01-02') | 
                                  ('1955-01-03' < sc['dateDecision']) & (sc['dateDecision'] < '1981-01-02') | 
                                  ('1987-01-03' < sc['dateDecision']) & (sc['dateDecision'] < '1995-01-02') |
                                  ('2001-01-03' < sc['dateDecision']) & (sc['dateDecision'] < '2002-11-11') | 
                                  ('2007-01-03' < sc['dateDecision']) & (sc['dateDecision'] < '2017-01-02'),
                                  'Democrat','Republican')

sc['partyOfSenate'].value_counts(normalize=True)
# Out:
# Democrat      0.712404
# Republican    0.287596
# Name: partyOfSenate, dtype: float64

# %%
sc.head()
# Out:
#      caseId     docketId                voteId dateDecision  decisionType  \
# 0  1946-001  1946-001-01  1946-001-01-01-01-01   1946-11-18             1
# 1  1946-001  1946-001-01  1946-001-01-01-01-02   1946-11-18             1
# 2  1946-001  1946-001-01  1946-001-01-01-01-03   1946-11-18             1
# 3  1946-001  1946-001-01  1946-001-01-01-01-04   1946-11-18             1
# 4  1946-001  1946-001-01  1946-001-01-01-01-05   1946-11-18             1
#
#        ledCite  term  naturalCourt   chief docket  ... minVotes justice  \
# 0  91 L. Ed. 3  1946          1301  Vinson     24  ...        1      86
# 1  91 L. Ed. 3  1946          1301  Vinson     24  ...        1      84
# 2  91 L. Ed. 3  1946          1301  Vinson     24  ...        1      81
# 3  91 L. Ed. 3  1946          1301  Vinson     24  ...        1      80
# 4  91 L. Ed. 3  1946          1301  Vinson     24  ...        1      79
#
#     justiceName  vote  opinion  direction  majority  partyOfPresident  \
# 0      HHBurton   2.0      1.0        1.0       1.0          Democrat
# 1     RHJackson   1.0      1.0        2.0       2.0          Democrat
# 2     WODouglas   1.0      1.0        2.0       2.0          Democrat
# 3  FFrankfurter   4.0      2.0        2.0       2.0          Democrat
# 4        SFReed   1.0      1.0        2.0       2.0          Democrat
#
#    partyOfAppointing  partyOfSenate
# 0           Democrat       Democrat
# 1           Democrat       Democrat
# 2           Democrat       Democrat
# 3         Republican       Democrat
# 4           Democrat       Democrat
#
# [5 rows x 60 columns]

# %%
pd.set_option('display.max_columns',100)
    
sc.head(10)
# Out:
#      caseId     docketId                voteId dateDecision  decisionType  \
# 0  1946-001  1946-001-01  1946-001-01-01-01-01   1946-11-18             1
# 1  1946-001  1946-001-01  1946-001-01-01-01-02   1946-11-18             1
# 2  1946-001  1946-001-01  1946-001-01-01-01-03   1946-11-18             1
# 3  1946-001  1946-001-01  1946-001-01-01-01-04   1946-11-18             1
# 4  1946-001  1946-001-01  1946-001-01-01-01-05   1946-11-18             1
# 5  1946-001  1946-001-01  1946-001-01-01-01-06   1946-11-18             1
# 6  1946-001  1946-001-01  1946-001-01-01-01-07   1946-11-18             1
# 7  1946-001  1946-001-01  1946-001-01-01-01-08   1946-11-18             1
# 8  1946-001  1946-001-01  1946-001-01-01-01-09   1946-11-18             1
# 9  1946-002  1946-002-01  1946-002-01-01-01-01   1946-11-18             1
#
#         ledCite  term  naturalCourt   chief docket  \
# 0   91 L. Ed. 3  1946          1301  Vinson     24
# 1   91 L. Ed. 3  1946          1301  Vinson     24
# 2   91 L. Ed. 3  1946          1301  Vinson     24
# 3   91 L. Ed. 3  1946          1301  Vinson     24
# 4   91 L. Ed. 3  1946          1301  Vinson     24
# 5   91 L. Ed. 3  1946          1301  Vinson     24
# 6   91 L. Ed. 3  1946          1301  Vinson     24
# 7   91 L. Ed. 3  1946          1301  Vinson     24
# 8   91 L. Ed. 3  1946          1301  Vinson     24
# 9  91 L. Ed. 12  1946          1301  Vinson     12
#
#                                             caseName dateArgument dateRearg  \
# 0  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 1  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 2  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 3  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 4  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 5  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 6  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 7  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 8  HALLIBURTON OIL WELL CEMENTING CO. v. WALKER e...       1/9/46  10/23/46
# 9                         CLEVELAND v. UNITED STATES     10/10/45  10/17/46
#
#    petitioner  petitionerState  respondent  respondentState  jurisdiction  \
# 0       198.0              NaN       172.0              NaN             6
# 1       198.0              NaN       172.0              NaN             6
# 2       198.0              NaN       172.0              NaN             6
# 3       198.0              NaN       172.0              NaN             6
# 4       198.0              NaN       172.0              NaN             6
# 5       198.0              NaN       172.0              NaN             6
# 6       198.0              NaN       172.0              NaN             6
# 7       198.0              NaN       172.0              NaN             6
# 8       198.0              NaN       172.0              NaN             6
# 9       100.0              NaN        27.0              NaN             1
#
#    adminAction  adminActionState  threeJudgeFdc  caseOrigin  caseOriginState  \
# 0          NaN               NaN            0.0        51.0              6.0
# 1          NaN               NaN            0.0        51.0              6.0
# 2          NaN               NaN            0.0        51.0              6.0
# 3          NaN               NaN            0.0        51.0              6.0
# 4          NaN               NaN            0.0        51.0              6.0
# 5          NaN               NaN            0.0        51.0              6.0
# 6          NaN               NaN            0.0        51.0              6.0
# 7          NaN               NaN            0.0        51.0              6.0
# 8          NaN               NaN            0.0        51.0              6.0
# 9          NaN               NaN            0.0       123.0             52.0
#
#    caseSource  caseSourceState  lcDisagreement  firstAgreement  \
# 0        29.0              NaN             0.0             NaN
# 1        29.0              NaN             0.0             NaN
# 2        29.0              NaN             0.0             NaN
# 3        29.0              NaN             0.0             NaN
# 4        29.0              NaN             0.0             NaN
# 5        29.0              NaN             0.0             NaN
# 6        29.0              NaN             0.0             NaN
# 7        29.0              NaN             0.0             NaN
# 8        29.0              NaN             0.0             NaN
# 9        30.0              NaN             0.0             NaN
#
#    secondAgreement  ï»¿certReason  lcDisposition  lcDispositionDirection  \
# 0              NaN           11.0            2.0                     1.0
# 1              NaN           11.0            2.0                     1.0
# 2              NaN           11.0            2.0                     1.0
# 3              NaN           11.0            2.0                     1.0
# 4              NaN           11.0            2.0                     1.0
# 5              NaN           11.0            2.0                     1.0
# 6              NaN           11.0            2.0                     1.0
# 7              NaN           11.0            2.0                     1.0
# 8              NaN           11.0            2.0                     1.0
# 9              NaN            4.0            2.0                     1.0
#
#    declarationUncon  caseDisposition  caseDispositionUnusual  partyWinning  \
# 0               1.0              3.0                     0.0           1.0
# 1               1.0              3.0                     0.0           1.0
# 2               1.0              3.0                     0.0           1.0
# 3               1.0              3.0                     0.0           1.0
# 4               1.0              3.0                     0.0           1.0
# 5               1.0              3.0                     0.0           1.0
# 6               1.0              3.0                     0.0           1.0
# 7               1.0              3.0                     0.0           1.0
# 8               1.0              3.0                     0.0           1.0
# 9               1.0              2.0                     0.0           0.0
#
#    precedentAlteration  voteUnclear    issue  issueArea  decisionDirection  \
# 0                  1.0          0.0  80180.0        8.0                2.0
# 1                  1.0          0.0  80180.0        8.0                2.0
# 2                  1.0          0.0  80180.0        8.0                2.0
# 3                  1.0          0.0  80180.0        8.0                2.0
# 4                  1.0          0.0  80180.0        8.0                2.0
# 5                  1.0          0.0  80180.0        8.0                2.0
# 6                  1.0          0.0  80180.0        8.0                2.0
# 7                  1.0          0.0  80180.0        8.0                2.0
# 8                  1.0          0.0  80180.0        8.0                2.0
# 9                  0.0          0.0  10500.0        1.0                1.0
#
#    decisionDirectionDissent  authorityDecision1  authorityDecision2  lawType  \
# 0                       0.0                 4.0                 NaN      6.0
# 1                       0.0                 4.0                 NaN      6.0
# 2                       0.0                 4.0                 NaN      6.0
# 3                       0.0                 4.0                 NaN      6.0
# 4                       0.0                 4.0                 NaN      6.0
# 5                       0.0                 4.0                 NaN      6.0
# 6                       0.0                 4.0                 NaN      6.0
# 7                       0.0                 4.0                 NaN      6.0
# 8                       0.0                 4.0                 NaN      6.0
# 9                       0.0                 4.0                 NaN      6.0
#
#    lawSupp          lawMinor  majOpinWriter  majOpinAssigner  splitVote  \
# 0    600.0   35 U.S.C. Ã 33           78.0             78.0          1
# 1    600.0   35 U.S.C. Ã 33           78.0             78.0          1
# 2    600.0   35 U.S.C. Ã 33           78.0             78.0          1
# 3    600.0   35 U.S.C. Ã 33           78.0             78.0          1
# 4    600.0   35 U.S.C. Ã 33           78.0             78.0          1
# 5    600.0   35 U.S.C. Ã 33           78.0             78.0          1
# 6    600.0   35 U.S.C. Ã 33           78.0             78.0          1
# 7    600.0   35 U.S.C. Ã 33           78.0             78.0          1
# 8    600.0   35 U.S.C. Ã 33           78.0             78.0          1
# 9    600.0  18 U.S.C. Ã 398           81.0             87.0          1
#
#    majVotes  minVotes  justice   justiceName  vote  opinion  direction  \
# 0         8         1       86      HHBurton   2.0      1.0        1.0
# 1         8         1       84     RHJackson   1.0      1.0        2.0
# 2         8         1       81     WODouglas   1.0      1.0        2.0
# 3         8         1       80  FFrankfurter   4.0      2.0        2.0
# 4         8         1       79        SFReed   1.0      1.0        2.0
# 5         8         1       78       HLBlack   1.0      2.0        2.0
# 6         8         1       85    WBRutledge   1.0      1.0        2.0
# 7         8         1       82       FMurphy   1.0      1.0        2.0
# 8         8         1       87      FMVinson   1.0      1.0        2.0
# 9         6         3       86      HHBurton   1.0      1.0        1.0
#
#    majority partyOfPresident partyOfAppointing partyOfSenate
# 0       1.0         Democrat          Democrat      Democrat
# 1       2.0         Democrat          Democrat      Democrat
# 2       2.0         Democrat          Democrat      Democrat
# 3       2.0         Democrat        Republican      Democrat
# 4       2.0         Democrat          Democrat      Democrat
# 5       2.0         Democrat          Democrat      Democrat
# 6       2.0         Democrat          Democrat      Democrat
# 7       2.0         Democrat        Republican      Democrat
# 8       2.0         Democrat          Democrat      Democrat
# 9       2.0         Democrat          Democrat      Democrat

# %%
# Retrain features to be categorical for OneHotEncoding

all_columns = list(sc)
sc[all_columns] = sc[all_columns].astype(str)

# %%
sc['direction'] = sc['direction'].replace({'nan':'-1'})

# %%
sc['direction'].value_counts(normalize=True)
# Out:
# 2.0    0.496666
# 1.0    0.447419
# -1     0.055915
# Name: direction, dtype: float64

# %%
# Rename encoded column name 

sc.rename(columns={'ï»¿certReason':'certReason'}, inplace=True)

sc.columns
# Out:
# Index(['caseId', 'docketId', 'voteId', 'dateDecision', 'decisionType',
#        'ledCite', 'term', 'naturalCourt', 'chief', 'docket', 'caseName',
#        'dateArgument', 'dateRearg', 'petitioner', 'petitionerState',
#        'respondent', 'respondentState', 'jurisdiction', 'adminAction',
#        'adminActionState', 'threeJudgeFdc', 'caseOrigin', 'caseOriginState',
#        'caseSource', 'caseSourceState', 'lcDisagreement', 'firstAgreement',
#        'secondAgreement', 'certReason', 'lcDisposition',
#        'lcDispositionDirection', 'declarationUncon', 'caseDisposition',
#        'caseDispositionUnusual', 'partyWinning', 'precedentAlteration',
#        'voteUnclear', 'issue', 'issueArea', 'decisionDirection',
#        'decisionDirectionDissent', 'authorityDecision1', 'authorityDecision2',
#        'lawType', 'lawSupp', 'lawMinor', 'majOpinWriter', 'majOpinAssigner',
#        'splitVote', 'majVotes', 'minVotes', 'justice', 'justiceName', 'vote',
#        'opinion', 'direction', 'majority', 'partyOfPresident',
#        'partyOfAppointing', 'partyOfSenate'],
#       dtype='object')

# %%
# Drop all variables but our permutation importances results

sc = sc[['partyWinning','petitioner','respondent','caseSource','caseOrigin','certReason',
         'lcDisposition','issueArea','issue','lawType','lawSupp',]]

sc.head()
# Out:
#   partyWinning petitioner respondent caseSource caseOrigin certReason  \
# 0          1.0      198.0      172.0       29.0       51.0       11.0
# 1          1.0      198.0      172.0       29.0       51.0       11.0
# 2          1.0      198.0      172.0       29.0       51.0       11.0
# 3          1.0      198.0      172.0       29.0       51.0       11.0
# 4          1.0      198.0      172.0       29.0       51.0       11.0
#
#   lcDisposition issueArea    issue lawType lawSupp
# 0           2.0       8.0  80180.0     6.0   600.0
# 1           2.0       8.0  80180.0     6.0   600.0
# 2           2.0       8.0  80180.0     6.0   600.0
# 3           2.0       8.0  80180.0     6.0   600.0
# 4           2.0       8.0  80180.0     6.0   600.0

# %%
sc.shape
# Out:
# (120558, 11)

# %%
# Reassign the outcome variables so that only petitioner or not-petitioner wins

sc['partyWinning'] = sc['partyWinning'].replace(['nan','2.0'],'0.0')

sc['partyWinning'].value_counts(normalize=True)
# Out:
# 1.0    0.618781
# 0.0    0.381219
# Name: partyWinning, dtype: float64

# %%
# Assign understandable values to the coded values for issue area

sc['issueArea'] = sc['issueArea'].replace({'1.0':'1 - Criminal Procedure',
                                           '2.0':'2 - Civil Rights',
                                           '3.0':'3 - First Amendment',
                                           '4.0':'4 - Due Process',
                                           '5.0':'5 - Privacy',
                                           '6.0':'6 - Attorneys',
                                           '7.0':'7 - Unions',
                                           '8.0':'8 - Economic Activity',
                                           '9.0':'9 - Judicial Power',
                                           '10.0':'10 - Federalism',
                                           '11.0':'11 - Interstate Relations',
                                           '12.0':'12 - Federal Taxation',
                                           '13.0':'13 - Miscellaneous',
                                           '14.0':'14 - Private Action',
                                           'nan': '13 - Miscellaneous'}) 

sc['issueArea'].value_counts()
# Out:
# 1 - Criminal Procedure       24113
# 8 - Economic Activity        23360
# 2 - Civil Rights             19630
# 9 - Judicial Power           18259
# 3 - First Amendment          10396
# 10 - Federalism               6176
# 4 - Due Process               5361
# 7 - Unions                    4670
# 12 - Federal Taxation         3546
# 5 - Privacy                   1536
# 6 - Attorneys                 1248
# 13 - Miscellaneous            1213
# 11 - Interstate Relations     1005
# 14 - Private Action             45
# Name: issueArea, dtype: int64

# %%
# # Assign understandable values to the coded values for lower court disposition

sc['lcDisposition'] = sc['lcDisposition'].replace({'1.0':'1 - Stay, petition, or motion granted',
                                           '2.0':'2 - Affirmed',
                                           '3.0':'3 - Reversed',
                                           '4.0':'4 - Reversed and remanded',
                                           '5.0':'5 - Vacated and remanded',
                                           '6.0':'6 - Affirmed and reversed (or vacated) in part',
                                           '7.0':'7 - Affirmed and reversed (or vacated) in part and remanded',
                                           '8.0':'8 - Vacated',
                                           '9.0':'9 - Petition denied or appeal dismissed',
                                           '10.0':'10 - Modify',
                                           '11.0':'11 - Remand',
                                           '12.0':'12 - Unusual disposition',
                                           'nan': '12 - Unspecified'}) 

sc['lcDisposition'].value_counts()
# Out:
# 2 - Affirmed                                                   51567
# 3 - Reversed                                                   25846
# 12 - Unspecified                                               20164
# 9 - Petition denied or appeal dismissed                         5961
# 4 - Reversed and remanded                                       5327
# 6 - Affirmed and reversed (or vacated) in part                  2582
# 8 - Vacated                                                     2559
# 5 - Vacated and remanded                                        2225
# 12 - Unusual disposition                                        1268
# 1 - Stay, petition, or motion granted                           1011
# 7 - Affirmed and reversed (or vacated) in part and remanded      944
# 11 - Remand                                                      774
# 10 - Modify                                                      330
# Name: lcDisposition, dtype: int64

# %%
# # Assign understandable values to the coded values for lower court disposition

sc['lcDisposition'] = sc['lcDisposition'].replace({'1.0':'1 - Stay, petition, or motion granted',
                                           '2.0':'2 - Affirmed',
                                           '3.0':'3 - Reversed',
                                           '4.0':'4 - Reversed and remanded',
                                           '5.0':'5 - Vacated and remanded',
                                           '6.0':'6 - Affirmed and reversed (or vacated) in part',
                                           '7.0':'7 - Affirmed and reversed (or vacated) in part and remanded',
                                           '8.0':'8 - Vacated',
                                           '9.0':'9 - Petition denied or appeal dismissed',
                                           '10.0':'10 - Modify',
                                           '11.0':'11 - Remand',
                                           '12.0':'12 - Unusual disposition',
                                           'nan': '12 - Unspecified'}) 

sc['lcDisposition'].value_counts()
# Out:
# 2 - Affirmed                                                   51567
# 3 - Reversed                                                   25846
# 12 - Unspecified                                               20164
# 9 - Petition denied or appeal dismissed                         5961
# 4 - Reversed and remanded                                       5327
# 6 - Affirmed and reversed (or vacated) in part                  2582
# 8 - Vacated                                                     2559
# 5 - Vacated and remanded                                        2225
# 12 - Unusual disposition                                        1268
# 1 - Stay, petition, or motion granted                           1011
# 7 - Affirmed and reversed (or vacated) in part and remanded      944
# 11 - Remand                                                      774
# 10 - Modify                                                      330
# Name: lcDisposition, dtype: int64

# %%
# Assign understandable values to the coded values for cert reason 

sc['certReason'] = sc['certReason'].replace({'1.0':'1 - Case did not arise on cert or cert not granted',
                                           '2.0':'2 - Federal court conflict',
                                           '3.0':'3 - Federal court conflict and to resolve important or significant question',
                                           '4.0':'4 - Putative conflict',
                                           '5.0':'5 - Conflict between federal court and state court',
                                           '6.0':'6 - State court conflict',
                                           '7.0':'7 - Federal court confusion or uncertainty',
                                           '8.0':'8 - State court confusion or uncertainty',
                                           '9.0':'9 - Federal court and state court confusion or uncertainty',
                                           '10.0':'10 - To resolve important or significant question',
                                           '11.0':'11 - To resolve question presented',
                                           '12.0':'12 - No reason given',
                                           '13.0':'13 - Other reason',
                                           'nan': '12 - No reason given'}) 

sc['certReason'].value_counts()
# Out:
# 12 - No reason given                                                           41451
# 1 - Case did not arise on cert or cert not granted                             28954
# 11 - To resolve question presented                                             16213
# 2 - Federal court conflict                                                     15281
# 10 - To resolve important or significant question                              10854
# 3 - Federal court conflict and to resolve important or significant question     2656
# 4 - Putative conflict                                                           1606
# 13 - Other reason                                                               1254
# 5 - Conflict between federal court and state court                              1142
# 7 - Federal court confusion or uncertainty                                       501
# 6 - State court conflict                                                         467
# 9 - Federal court and state court confusion or uncertainty                       125
# 8 - State court confusion or uncertainty                                          54
# Name: certReason, dtype: int64

# %%
sc.isnull().sum()
# Out:
# partyWinning     0
# petitioner       0
# respondent       0
# caseSource       0
# caseOrigin       0
# certReason       0
# lcDisposition    0
# issueArea        0
# issue            0
# lawType          0
# lawSupp          0
# dtype: int64

# %%
# Split the dataframe into train and test sets 

from sklearn.model_selection import train_test_split

train, test = train_test_split(sc, train_size=0.9, test_size=0.10, 
                              stratify=sc['partyWinning'], random_state=42)

# %%
train, val = train_test_split(train, train_size=0.85, test_size=0.15, 
                              stratify=train['partyWinning'], random_state=42)

# %%
train.shape, val.shape, test.shape
# Out:
# ((92226, 11), (16276, 11), (12056, 11))

# %%
# Define target feature

target = 'partyWinning'

X_train = train.drop(columns=target)
y_train = train[target]
X_val = val.drop(columns=target)
y_val = val[target]
X_test = test.drop(columns=target)
y_test = test[target]

# %%
import numpy as np
import category_encoders as ce
from sklearn.preprocessing import RobustScaler
from sklearn.impute import SimpleImputer
from xgboost import XGBClassifier
from sklearn.pipeline import make_pipeline

# %%
import category_encoders as ce
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from xgboost import XGBClassifier

processor = make_pipeline(
    ce.OrdinalEncoder(), 
    SimpleImputer(strategy='median')
)

X_train_processed = processor.fit_transform(X_train)
X_val_processed = processor.transform(X_val)

eval_set = [(X_train_processed, y_train), 
            (X_val_processed, y_val)]

model = XGBClassifier(n_estimators=1000, n_jobs=-1)
model.fit(X_train_processed, y_train, eval_set=eval_set, eval_metric='auc', 
          early_stopping_rounds=10)
# Out:
# [0]	validation_0-auc:0.570096	validation_1-auc:0.569289
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 10 rounds.
# [1]	validation_0-auc:0.576021	validation_1-auc:0.57464
# [2]	validation_0-auc:0.578477	validation_1-auc:0.576657
# [3]	validation_0-auc:0.595835	validation_1-auc:0.592818
# [4]	validation_0-auc:0.609861	validation_1-auc:0.607593
# [5]	validation_0-auc:0.619107	validation_1-auc:0.61708
# [6]	validation_0-auc:0.633209	validation_1-auc:0.629756
# [7]	validation_0-auc:0.633734	validation_1-auc:0.62932
# [8]	validation_0-auc:0.640097	validation_1-auc:0.636748
# [9]	validation_0-auc:0.640834	validation_1-auc:0.637513
# [10]	validation_0-auc:0.645335	validation_1-auc:0.641194
# [11]	validation_0-auc:0.644055	validation_1-auc:0.639369
# [12]	validation_0-auc:0.651846	validation_1-auc:0.648161
# [13]	validation_0-auc:0.653199	validation_1-auc:0.649038
# [14]	validation_0-auc:0.654634	validation_1-auc:0.650581
# [15]	validation_0-auc:0.656501	validation_1-auc:0.65254
# [16]	validation_0-auc:0.659132	validation_1-auc:0.654639
# [17]	validation_0-auc:0.662027	validation_1-auc:0.657179
# [18]	validation_0-auc:0.666962	validation_1-auc:0.661613
# [19]	validation_0-auc:0.666123	validation_1-auc:0.660669
# [20]	validation_0-auc:0.667056	validation_1-auc:0.661483
# [21]	validation_0-auc:0.668182	validation_1-auc:0.663295
# [22]	validation_0-auc:0.669595	validation_1-auc:0.664744
# [23]	validation_0-auc:0.671643	validation_1-auc:0.666499
# [24]	validation_0-auc:0.672081	validation_1-auc:0.66666
# [25]	validation_0-auc:0.67315	validation_1-auc:0.667507
# [26]	validation_0-auc:0.674145	validation_1-auc:0.66834
# [27]	validation_0-auc:0.675849	validation_1-auc:0.669743
# [28]	validation_0-auc:0.677667	validation_1-auc:0.672058
# [29]	validation_0-auc:0.677307	validation_1-auc:0.671565
# [30]	validation_0-auc:0.679785	validation_1-auc:0.674114
# [31]	validation_0-auc:0.680505	validation_1-auc:0.674602
# [32]	validation_0-auc:0.68088	validation_1-auc:0.675021
# [33]	validation_0-auc:0.682166	validation_1-auc:0.675977
# [34]	validation_0-auc:0.68389	validation_1-auc:0.677543
# [35]	validation_0-auc:0.684273	validation_1-auc:0.677912
# [36]	validation_0-auc:0.684328	validation_1-auc:0.678084
# [37]	validation_0-auc:0.685816	validation_1-auc:0.67943
# [38]	validation_0-auc:0.687337	validation_1-auc:0.680921
# [39]	validation_0-auc:0.689781	validation_1-auc:0.68266
# [40]	validation_0-auc:0.69038	validation_1-auc:0.683287
# [41]	validation_0-auc:0.691888	validation_1-auc:0.684622
# [42]	validation_0-auc:0.692547	validation_1-auc:0.685277
# [43]	validation_0-auc:0.69325	validation_1-auc:0.685938
# [44]	validation_0-auc:0.693672	validation_1-auc:0.686249
# [45]	validation_0-auc:0.694192	validation_1-auc:0.686759
# [46]	validation_0-auc:0.696051	validation_1-auc:0.688882
# [47]	validation_0-auc:0.696984	validation_1-auc:0.689666
# [48]	validation_0-auc:0.697727	validation_1-auc:0.689984
# [49]	validation_0-auc:0.699236	validation_1-auc:0.691012
# [50]	validation_0-auc:0.699653	validation_1-auc:0.691561
# [51]	validation_0-auc:0.700302	validation_1-auc:0.692399
# [52]	validation_0-auc:0.702305	validation_1-auc:0.69454
# [53]	validation_0-auc:0.702187	validation_1-auc:0.69442
# [54]	validation_0-auc:0.702629	validation_1-auc:0.694866
# [55]	validation_0-auc:0.703466	validation_1-auc:0.69567
# [56]	validation_0-auc:0.703558	validation_1-auc:0.695836
# [57]	validation_0-auc:0.704232	validation_1-auc:0.696729
# [58]	validation_0-auc:0.704944	validation_1-auc:0.697204
# [59]	validation_0-auc:0.705468	validation_1-auc:0.697464
# [60]	validation_0-auc:0.706236	validation_1-auc:0.698016
# [61]	validation_0-auc:0.707083	validation_1-auc:0.698694
# [62]	validation_0-auc:0.708282	validation_1-auc:0.699916
# [63]	validation_0-auc:0.708753	validation_1-auc:0.700361
# [64]	validation_0-auc:0.709656	validation_1-auc:0.701114
# [65]	validation_0-auc:0.709797	validation_1-auc:0.701271
# [66]	validation_0-auc:0.710596	validation_1-auc:0.702009
# [67]	validation_0-auc:0.711039	validation_1-auc:0.702527
# [68]	validation_0-auc:0.71169	validation_1-auc:0.703088
# [69]	validation_0-auc:0.712764	validation_1-auc:0.704053
# [70]	validation_0-auc:0.713207	validation_1-auc:0.70436
# [71]	validation_0-auc:0.713783	validation_1-auc:0.704798
# [72]	validation_0-auc:0.713993	validation_1-auc:0.705178
# [73]	validation_0-auc:0.714236	validation_1-auc:0.705485
# [74]	validation_0-auc:0.714651	validation_1-auc:0.705831
# [75]	validation_0-auc:0.715393	validation_1-auc:0.706523
# [76]	validation_0-auc:0.715957	validation_1-auc:0.70708
# [77]	validation_0-auc:0.716201	validation_1-auc:0.707191
# [78]	validation_0-auc:0.716822	validation_1-auc:0.707872
# [79]	validation_0-auc:0.717124	validation_1-auc:0.708281
# [80]	validation_0-auc:0.717573	validation_1-auc:0.708632
# [81]	validation_0-auc:0.718008	validation_1-auc:0.709145
# [82]	validation_0-auc:0.718124	validation_1-auc:0.709276
# [83]	validation_0-auc:0.718392	validation_1-auc:0.709465
# [84]	validation_0-auc:0.718877	validation_1-auc:0.709977
# [85]	validation_0-auc:0.719091	validation_1-auc:0.710186
# [86]	validation_0-auc:0.719385	validation_1-auc:0.710364
# [87]	validation_0-auc:0.720025	validation_1-auc:0.711085
# [88]	validation_0-auc:0.720231	validation_1-auc:0.711458
# [89]	validation_0-auc:0.721017	validation_1-auc:0.712036
# [90]	validation_0-auc:0.721351	validation_1-auc:0.712209
# [91]	validation_0-auc:0.7225	validation_1-auc:0.713288
# [92]	validation_0-auc:0.722711	validation_1-auc:0.713446
# [93]	validation_0-auc:0.723531	validation_1-auc:0.714551
# [94]	validation_0-auc:0.723493	validation_1-auc:0.714537
# [95]	validation_0-auc:0.723739	validation_1-auc:0.714779
# [96]	validation_0-auc:0.724276	validation_1-auc:0.715329
# [97]	validation_0-auc:0.725703	validation_1-auc:0.716501
# [98]	validation_0-auc:0.726375	validation_1-auc:0.717273
# [99]	validation_0-auc:0.727344	validation_1-auc:0.718053
# [100]	validation_0-auc:0.728147	validation_1-auc:0.718597
# [101]	validation_0-auc:0.728936	validation_1-auc:0.719465
# [102]	validation_0-auc:0.730012	validation_1-auc:0.720372
# [103]	validation_0-auc:0.730555	validation_1-auc:0.721145
# [104]	validation_0-auc:0.731609	validation_1-auc:0.722174
# [105]	validation_0-auc:0.732128	validation_1-auc:0.722333
# [106]	validation_0-auc:0.732274	validation_1-auc:0.722388
# [107]	validation_0-auc:0.732467	validation_1-auc:0.722598
# [108]	validation_0-auc:0.732742	validation_1-auc:0.722897
# [109]	validation_0-auc:0.732821	validation_1-auc:0.722994
# [110]	validation_0-auc:0.732955	validation_1-auc:0.723127
# [111]	validation_0-auc:0.733272	validation_1-auc:0.723321
# [112]	validation_0-auc:0.733371	validation_1-auc:0.723431
# [113]	validation_0-auc:0.73372	validation_1-auc:0.723687
# [114]	validation_0-auc:0.733784	validation_1-auc:0.723777
# [115]	validation_0-auc:0.733837	validation_1-auc:0.7238
# [116]	validation_0-auc:0.73395	validation_1-auc:0.723892
# [117]	validation_0-auc:0.734772	validation_1-auc:0.724814
# [118]	validation_0-auc:0.73535	validation_1-auc:0.725183
# [119]	validation_0-auc:0.735947	validation_1-auc:0.725936
# [120]	validation_0-auc:0.736725	validation_1-auc:0.726538
# [121]	validation_0-auc:0.737344	validation_1-auc:0.726994
# [122]	validation_0-auc:0.737739	validation_1-auc:0.727392
# [123]	validation_0-auc:0.73805	validation_1-auc:0.727577
# [124]	validation_0-auc:0.738369	validation_1-auc:0.727865
# [125]	validation_0-auc:0.738513	validation_1-auc:0.728044
# [126]	validation_0-auc:0.738715	validation_1-auc:0.7282
# [127]	validation_0-auc:0.739321	validation_1-auc:0.72889
# [128]	validation_0-auc:0.739371	validation_1-auc:0.728948
# [129]	validation_0-auc:0.739499	validation_1-auc:0.729061
# [130]	validation_0-auc:0.739612	validation_1-auc:0.729192
# [131]	validation_0-auc:0.740242	validation_1-auc:0.729826
# [132]	validation_0-auc:0.741186	validation_1-auc:0.730707
# [133]	validation_0-auc:0.741819	validation_1-auc:0.731209
# [134]	validation_0-auc:0.74226	validation_1-auc:0.731595
# [135]	validation_0-auc:0.742258	validation_1-auc:0.731577
# [136]	validation_0-auc:0.742588	validation_1-auc:0.731975
# [137]	validation_0-auc:0.743063	validation_1-auc:0.732501
# [138]	validation_0-auc:0.743193	validation_1-auc:0.732671
# [139]	validation_0-auc:0.743299	validation_1-auc:0.732765
# [140]	validation_0-auc:0.743867	validation_1-auc:0.733429
# [141]	validation_0-auc:0.744183	validation_1-auc:0.733602
# [142]	validation_0-auc:0.744654	validation_1-auc:0.733928
# [143]	validation_0-auc:0.744692	validation_1-auc:0.733987
# [144]	validation_0-auc:0.745061	validation_1-auc:0.734508
# [145]	validation_0-auc:0.74578	validation_1-auc:0.735173
# [146]	validation_0-auc:0.746005	validation_1-auc:0.735377
# [147]	validation_0-auc:0.746617	validation_1-auc:0.735971
# [148]	validation_0-auc:0.746652	validation_1-auc:0.736007
# [149]	validation_0-auc:0.746699	validation_1-auc:0.736177
# [150]	validation_0-auc:0.747367	validation_1-auc:0.736712
# [151]	validation_0-auc:0.747931	validation_1-auc:0.737296
# [152]	validation_0-auc:0.747823	validation_1-auc:0.737225
# [153]	validation_0-auc:0.748211	validation_1-auc:0.737779
# [154]	validation_0-auc:0.748421	validation_1-auc:0.7378
# [155]	validation_0-auc:0.748873	validation_1-auc:0.738302
# [156]	validation_0-auc:0.749265	validation_1-auc:0.738808
# [157]	validation_0-auc:0.749537	validation_1-auc:0.739319
# [158]	validation_0-auc:0.750328	validation_1-auc:0.739983
# [159]	validation_0-auc:0.750572	validation_1-auc:0.740199
# [160]	validation_0-auc:0.751029	validation_1-auc:0.740578
# [161]	validation_0-auc:0.751371	validation_1-auc:0.740967
# [162]	validation_0-auc:0.751635	validation_1-auc:0.741219
# [163]	validation_0-auc:0.751836	validation_1-auc:0.741432
# [164]	validation_0-auc:0.7519	validation_1-auc:0.741469
# [165]	validation_0-auc:0.751926	validation_1-auc:0.741475
# [166]	validation_0-auc:0.751932	validation_1-auc:0.741486
# [167]	validation_0-auc:0.752222	validation_1-auc:0.741853
# [168]	validation_0-auc:0.752551	validation_1-auc:0.742089
# [169]	validation_0-auc:0.75281	validation_1-auc:0.742404
# [170]	validation_0-auc:0.753034	validation_1-auc:0.742584
# [171]	validation_0-auc:0.753113	validation_1-auc:0.742656
# [172]	validation_0-auc:0.753475	validation_1-auc:0.742937
# [173]	validation_0-auc:0.753741	validation_1-auc:0.74315
# [174]	validation_0-auc:0.753849	validation_1-auc:0.743209
# [175]	validation_0-auc:0.754331	validation_1-auc:0.743846
# [176]	validation_0-auc:0.754397	validation_1-auc:0.7439
# [177]	validation_0-auc:0.754629	validation_1-auc:0.744091
# [178]	validation_0-auc:0.755253	validation_1-auc:0.74469
# [179]	validation_0-auc:0.755682	validation_1-auc:0.744993
# [180]	validation_0-auc:0.755879	validation_1-auc:0.745182
# [181]	validation_0-auc:0.755764	validation_1-auc:0.745097
# [182]	validation_0-auc:0.756089	validation_1-auc:0.745685
# [183]	validation_0-auc:0.756513	validation_1-auc:0.746172
# [184]	validation_0-auc:0.757019	validation_1-auc:0.746782
# [185]	validation_0-auc:0.757176	validation_1-auc:0.746914
# [186]	validation_0-auc:0.757277	validation_1-auc:0.746928
# [187]	validation_0-auc:0.757338	validation_1-auc:0.746969
# [188]	validation_0-auc:0.757725	validation_1-auc:0.747484
# [189]	validation_0-auc:0.758133	validation_1-auc:0.748043
# [190]	validation_0-auc:0.758371	validation_1-auc:0.748342
# [191]	validation_0-auc:0.758749	validation_1-auc:0.748706
# [192]	validation_0-auc:0.758822	validation_1-auc:0.748725
# [193]	validation_0-auc:0.759901	validation_1-auc:0.749712
# [194]	validation_0-auc:0.760335	validation_1-auc:0.750259
# [195]	validation_0-auc:0.760539	validation_1-auc:0.750221
# [196]	validation_0-auc:0.760933	validation_1-auc:0.750535
# [197]	validation_0-auc:0.761281	validation_1-auc:0.75091
# [198]	validation_0-auc:0.76175	validation_1-auc:0.751237
# [199]	validation_0-auc:0.761856	validation_1-auc:0.751285
# [200]	validation_0-auc:0.761945	validation_1-auc:0.751368
# [201]	validation_0-auc:0.761989	validation_1-auc:0.751387
# [202]	validation_0-auc:0.762057	validation_1-auc:0.75144
# [203]	validation_0-auc:0.762121	validation_1-auc:0.751495
# [204]	validation_0-auc:0.762369	validation_1-auc:0.751778
# [205]	validation_0-auc:0.762864	validation_1-auc:0.752211
# [206]	validation_0-auc:0.76311	validation_1-auc:0.752478
# [207]	validation_0-auc:0.763133	validation_1-auc:0.752497
# [208]	validation_0-auc:0.763575	validation_1-auc:0.753017
# [209]	validation_0-auc:0.763822	validation_1-auc:0.753222
# [210]	validation_0-auc:0.76418	validation_1-auc:0.753656
# [211]	validation_0-auc:0.764296	validation_1-auc:0.753787
# [212]	validation_0-auc:0.7647	validation_1-auc:0.75437
# [213]	validation_0-auc:0.764847	validation_1-auc:0.754499
# [214]	validation_0-auc:0.765159	validation_1-auc:0.754764
# [215]	validation_0-auc:0.765207	validation_1-auc:0.754646
# [216]	validation_0-auc:0.765824	validation_1-auc:0.755108
# [217]	validation_0-auc:0.766238	validation_1-auc:0.755507
# [218]	validation_0-auc:0.766566	validation_1-auc:0.755773
# [219]	validation_0-auc:0.766725	validation_1-auc:0.75594
# [220]	validation_0-auc:0.766791	validation_1-auc:0.755919
# [221]	validation_0-auc:0.767076	validation_1-auc:0.756203
# [222]	validation_0-auc:0.767492	validation_1-auc:0.756628
# [223]	validation_0-auc:0.767911	validation_1-auc:0.756991
# [224]	validation_0-auc:0.76801	validation_1-auc:0.757199
# [225]	validation_0-auc:0.768083	validation_1-auc:0.757183
# [226]	validation_0-auc:0.768321	validation_1-auc:0.757479
# [227]	validation_0-auc:0.768464	validation_1-auc:0.757631
# [228]	validation_0-auc:0.768675	validation_1-auc:0.757886
# [229]	validation_0-auc:0.768692	validation_1-auc:0.757899
# [230]	validation_0-auc:0.768993	validation_1-auc:0.758004
# [231]	validation_0-auc:0.76943	validation_1-auc:0.758505
# [232]	validation_0-auc:0.769475	validation_1-auc:0.758555
# [233]	validation_0-auc:0.769544	validation_1-auc:0.758581
# [234]	validation_0-auc:0.769575	validation_1-auc:0.758596
# [235]	validation_0-auc:0.769703	validation_1-auc:0.758738
# [236]	validation_0-auc:0.769747	validation_1-auc:0.758744
# [237]	validation_0-auc:0.770249	validation_1-auc:0.759137
# [238]	validation_0-auc:0.770696	validation_1-auc:0.759457
# [239]	validation_0-auc:0.771004	validation_1-auc:0.759705
# [240]	validation_0-auc:0.771052	validation_1-auc:0.759734
# [241]	validation_0-auc:0.771284	validation_1-auc:0.759987
# [242]	validation_0-auc:0.771588	validation_1-auc:0.760382
# [243]	validation_0-auc:0.771989	validation_1-auc:0.760857
# [244]	validation_0-auc:0.772414	validation_1-auc:0.761155
# [245]	validation_0-auc:0.772767	validation_1-auc:0.761509
# [246]	validation_0-auc:0.77318	validation_1-auc:0.762108
# [247]	validation_0-auc:0.773385	validation_1-auc:0.76225
# [248]	validation_0-auc:0.773624	validation_1-auc:0.76249
# [249]	validation_0-auc:0.773753	validation_1-auc:0.762684
# [250]	validation_0-auc:0.773918	validation_1-auc:0.762827
# [251]	validation_0-auc:0.774146	validation_1-auc:0.763173
# [252]	validation_0-auc:0.77449	validation_1-auc:0.763464
# [253]	validation_0-auc:0.774582	validation_1-auc:0.763544
# [254]	validation_0-auc:0.775185	validation_1-auc:0.764058
# [255]	validation_0-auc:0.775849	validation_1-auc:0.764827
# [256]	validation_0-auc:0.775994	validation_1-auc:0.764956
# [257]	validation_0-auc:0.776506	validation_1-auc:0.765472
# [258]	validation_0-auc:0.776751	validation_1-auc:0.765744
# [259]	validation_0-auc:0.776983	validation_1-auc:0.765971
# [260]	validation_0-auc:0.777177	validation_1-auc:0.766124
# [261]	validation_0-auc:0.777198	validation_1-auc:0.766135
# [262]	validation_0-auc:0.777421	validation_1-auc:0.766363
# [263]	validation_0-auc:0.777527	validation_1-auc:0.766352
# [264]	validation_0-auc:0.777608	validation_1-auc:0.766414
# [265]	validation_0-auc:0.777896	validation_1-auc:0.766604
# [266]	validation_0-auc:0.778269	validation_1-auc:0.766925
# [267]	validation_0-auc:0.778553	validation_1-auc:0.767148
# [268]	validation_0-auc:0.779062	validation_1-auc:0.767538
# [269]	validation_0-auc:0.779125	validation_1-auc:0.767604
# [270]	validation_0-auc:0.779591	validation_1-auc:0.767983
# [271]	validation_0-auc:0.779983	validation_1-auc:0.768335
# [272]	validation_0-auc:0.780128	validation_1-auc:0.76847
# [273]	validation_0-auc:0.780292	validation_1-auc:0.768614
# [274]	validation_0-auc:0.780305	validation_1-auc:0.76862
# [275]	validation_0-auc:0.780624	validation_1-auc:0.768893
# [276]	validation_0-auc:0.781022	validation_1-auc:0.769312
# [277]	validation_0-auc:0.781161	validation_1-auc:0.769445
# [278]	validation_0-auc:0.781542	validation_1-auc:0.769994
# [279]	validation_0-auc:0.781815	validation_1-auc:0.770184
# [280]	validation_0-auc:0.782021	validation_1-auc:0.770328
# [281]	validation_0-auc:0.782221	validation_1-auc:0.77057
# [282]	validation_0-auc:0.782238	validation_1-auc:0.770584
# [283]	validation_0-auc:0.782407	validation_1-auc:0.770801
# [284]	validation_0-auc:0.78246	validation_1-auc:0.770878
# [285]	validation_0-auc:0.782563	validation_1-auc:0.770951
# [286]	validation_0-auc:0.782727	validation_1-auc:0.771233
# [287]	validation_0-auc:0.783071	validation_1-auc:0.771559
# [288]	validation_0-auc:0.783104	validation_1-auc:0.77157
# [289]	validation_0-auc:0.783399	validation_1-auc:0.772069
# [290]	validation_0-auc:0.783782	validation_1-auc:0.772475
# [291]	validation_0-auc:0.783976	validation_1-auc:0.772649
# [292]	validation_0-auc:0.784105	validation_1-auc:0.772798
# [293]	validation_0-auc:0.784418	validation_1-auc:0.77293
# [294]	validation_0-auc:0.784693	validation_1-auc:0.773083
# [295]	validation_0-auc:0.784797	validation_1-auc:0.773182
# [296]	validation_0-auc:0.785036	validation_1-auc:0.773464
# [297]	validation_0-auc:0.785066	validation_1-auc:0.773489
# [298]	validation_0-auc:0.78541	validation_1-auc:0.773879
# [299]	validation_0-auc:0.785558	validation_1-auc:0.774045
# [300]	validation_0-auc:0.785992	validation_1-auc:0.774586
# [301]	validation_0-auc:0.786103	validation_1-auc:0.774728
# [302]	validation_0-auc:0.786205	validation_1-auc:0.774639
# [303]	validation_0-auc:0.786479	validation_1-auc:0.77483
# [304]	validation_0-auc:0.786626	validation_1-auc:0.774974
# [305]	validation_0-auc:0.786814	validation_1-auc:0.775175
# [306]	validation_0-auc:0.78703	validation_1-auc:0.775347
# [307]	validation_0-auc:0.787068	validation_1-auc:0.77539
# [308]	validation_0-auc:0.787236	validation_1-auc:0.775544
# [309]	validation_0-auc:0.787278	validation_1-auc:0.775604
# [310]	validation_0-auc:0.787326	validation_1-auc:0.775652
# [311]	validation_0-auc:0.787619	validation_1-auc:0.775943
# [312]	validation_0-auc:0.787771	validation_1-auc:0.776203
# [313]	validation_0-auc:0.787804	validation_1-auc:0.776218
# [314]	validation_0-auc:0.787935	validation_1-auc:0.776356
# [315]	validation_0-auc:0.787984	validation_1-auc:0.776423
# [316]	validation_0-auc:0.788016	validation_1-auc:0.776453
# [317]	validation_0-auc:0.788337	validation_1-auc:0.776612
# [318]	validation_0-auc:0.788501	validation_1-auc:0.776689
# [319]	validation_0-auc:0.788686	validation_1-auc:0.776991
# [320]	validation_0-auc:0.788775	validation_1-auc:0.777067
# [321]	validation_0-auc:0.788983	validation_1-auc:0.777423
# [322]	validation_0-auc:0.789283	validation_1-auc:0.777616
# [323]	validation_0-auc:0.789678	validation_1-auc:0.777983
# [324]	validation_0-auc:0.78984	validation_1-auc:0.778163
# [325]	validation_0-auc:0.790073	validation_1-auc:0.778368
# [326]	validation_0-auc:0.790226	validation_1-auc:0.778511
# [327]	validation_0-auc:0.790628	validation_1-auc:0.778691
# [328]	validation_0-auc:0.790727	validation_1-auc:0.778835
# [329]	validation_0-auc:0.790788	validation_1-auc:0.778886
# [330]	validation_0-auc:0.791121	validation_1-auc:0.779308
# [331]	validation_0-auc:0.791335	validation_1-auc:0.779499
# [332]	validation_0-auc:0.791499	validation_1-auc:0.779781
# [333]	validation_0-auc:0.791561	validation_1-auc:0.779864
# [334]	validation_0-auc:0.79159	validation_1-auc:0.779897
# [335]	validation_0-auc:0.791635	validation_1-auc:0.779932
# [336]	validation_0-auc:0.791691	validation_1-auc:0.779975
# [337]	validation_0-auc:0.791992	validation_1-auc:0.780091
# [338]	validation_0-auc:0.792443	validation_1-auc:0.780588
# [339]	validation_0-auc:0.792787	validation_1-auc:0.781013
# [340]	validation_0-auc:0.793137	validation_1-auc:0.781418
# [341]	validation_0-auc:0.793315	validation_1-auc:0.781589
# [342]	validation_0-auc:0.79376	validation_1-auc:0.782169
# [343]	validation_0-auc:0.794026	validation_1-auc:0.782474
# [344]	validation_0-auc:0.794201	validation_1-auc:0.782595
# [345]	validation_0-auc:0.794406	validation_1-auc:0.782755
# [346]	validation_0-auc:0.794641	validation_1-auc:0.783067
# [347]	validation_0-auc:0.794717	validation_1-auc:0.783136
# [348]	validation_0-auc:0.7949	validation_1-auc:0.783394
# [349]	validation_0-auc:0.795266	validation_1-auc:0.783893
# [350]	validation_0-auc:0.795325	validation_1-auc:0.78396
# [351]	validation_0-auc:0.795601	validation_1-auc:0.784192
# [352]	validation_0-auc:0.79564	validation_1-auc:0.78422
# [353]	validation_0-auc:0.795663	validation_1-auc:0.784253
# [354]	validation_0-auc:0.795973	validation_1-auc:0.784677
# [355]	validation_0-auc:0.796263	validation_1-auc:0.784948
# [356]	validation_0-auc:0.796372	validation_1-auc:0.785061
# [357]	validation_0-auc:0.796581	validation_1-auc:0.78539
# [358]	validation_0-auc:0.796626	validation_1-auc:0.785493
# [359]	validation_0-auc:0.796816	validation_1-auc:0.785541
# [360]	validation_0-auc:0.797095	validation_1-auc:0.785837
# [361]	validation_0-auc:0.797251	validation_1-auc:0.785956
# [362]	validation_0-auc:0.797413	validation_1-auc:0.786004
# [363]	validation_0-auc:0.797709	validation_1-auc:0.7864
# [364]	validation_0-auc:0.797995	validation_1-auc:0.7867
# [365]	validation_0-auc:0.798164	validation_1-auc:0.78679
# [366]	validation_0-auc:0.798314	validation_1-auc:0.786962
# [367]	validation_0-auc:0.798316	validation_1-auc:0.786965
# [368]	validation_0-auc:0.798465	validation_1-auc:0.787225
# [369]	validation_0-auc:0.798573	validation_1-auc:0.787244
# [370]	validation_0-auc:0.798682	validation_1-auc:0.787351
# [371]	validation_0-auc:0.798919	validation_1-auc:0.7876
# [372]	validation_0-auc:0.799061	validation_1-auc:0.787749
# [373]	validation_0-auc:0.799458	validation_1-auc:0.788046
# [374]	validation_0-auc:0.799865	validation_1-auc:0.788487
# [375]	validation_0-auc:0.800017	validation_1-auc:0.788601
# [376]	validation_0-auc:0.800272	validation_1-auc:0.78888
# [377]	validation_0-auc:0.800284	validation_1-auc:0.7889
# [378]	validation_0-auc:0.800301	validation_1-auc:0.788925
# [379]	validation_0-auc:0.800317	validation_1-auc:0.788949
# [380]	validation_0-auc:0.800448	validation_1-auc:0.789073
# [381]	validation_0-auc:0.800673	validation_1-auc:0.789345
# [382]	validation_0-auc:0.800958	validation_1-auc:0.789684
# [383]	validation_0-auc:0.801158	validation_1-auc:0.789886
# [384]	validation_0-auc:0.801197	validation_1-auc:0.789909
# [385]	validation_0-auc:0.801281	validation_1-auc:0.789979
# [386]	validation_0-auc:0.801316	validation_1-auc:0.790025
# [387]	validation_0-auc:0.801348	validation_1-auc:0.790048
# [388]	validation_0-auc:0.801547	validation_1-auc:0.79023
# [389]	validation_0-auc:0.801854	validation_1-auc:0.790574
# [390]	validation_0-auc:0.802135	validation_1-auc:0.790919
# [391]	validation_0-auc:0.802148	validation_1-auc:0.790929
# [392]	validation_0-auc:0.802162	validation_1-auc:0.790962
# [393]	validation_0-auc:0.802302	validation_1-auc:0.791205
# [394]	validation_0-auc:0.802487	validation_1-auc:0.791329
# [395]	validation_0-auc:0.802711	validation_1-auc:0.791655
# [396]	validation_0-auc:0.802951	validation_1-auc:0.791922
# [397]	validation_0-auc:0.803224	validation_1-auc:0.792174
# [398]	validation_0-auc:0.803416	validation_1-auc:0.792447
# [399]	validation_0-auc:0.803587	validation_1-auc:0.792583
# [400]	validation_0-auc:0.80385	validation_1-auc:0.792823
# [401]	validation_0-auc:0.803881	validation_1-auc:0.792855
# [402]	validation_0-auc:0.804007	validation_1-auc:0.792911
# [403]	validation_0-auc:0.804025	validation_1-auc:0.792919
# [404]	validation_0-auc:0.804235	validation_1-auc:0.793076
# [405]	validation_0-auc:0.804472	validation_1-auc:0.793317
# [406]	validation_0-auc:0.804485	validation_1-auc:0.793338
# [407]	validation_0-auc:0.804825	validation_1-auc:0.793546
# [408]	validation_0-auc:0.804855	validation_1-auc:0.793585
# [409]	validation_0-auc:0.804859	validation_1-auc:0.793602
# [410]	validation_0-auc:0.805224	validation_1-auc:0.793957
# [411]	validation_0-auc:0.805362	validation_1-auc:0.794122
# [412]	validation_0-auc:0.805513	validation_1-auc:0.794276
# [413]	validation_0-auc:0.805578	validation_1-auc:0.794346
# [414]	validation_0-auc:0.805866	validation_1-auc:0.794569
# [415]	validation_0-auc:0.806081	validation_1-auc:0.794807
# [416]	validation_0-auc:0.806153	validation_1-auc:0.794875
# [417]	validation_0-auc:0.806466	validation_1-auc:0.79526
# [418]	validation_0-auc:0.80647	validation_1-auc:0.795269
# [419]	validation_0-auc:0.806721	validation_1-auc:0.795599
# [420]	validation_0-auc:0.807018	validation_1-auc:0.795805
# [421]	validation_0-auc:0.80713	validation_1-auc:0.795884
# [422]	validation_0-auc:0.807247	validation_1-auc:0.796017
# [423]	validation_0-auc:0.807422	validation_1-auc:0.796348
# [424]	validation_0-auc:0.807574	validation_1-auc:0.796452
# [425]	validation_0-auc:0.807587	validation_1-auc:0.796505
# [426]	validation_0-auc:0.807733	validation_1-auc:0.796679
# [427]	validation_0-auc:0.807789	validation_1-auc:0.796707
# [428]	validation_0-auc:0.808069	validation_1-auc:0.796993
# [429]	validation_0-auc:0.808244	validation_1-auc:0.797087
# [430]	validation_0-auc:0.80844	validation_1-auc:0.797248
# [431]	validation_0-auc:0.80844	validation_1-auc:0.797246
# [432]	validation_0-auc:0.808556	validation_1-auc:0.797304
# [433]	validation_0-auc:0.808769	validation_1-auc:0.797519
# [434]	validation_0-auc:0.808816	validation_1-auc:0.797563
# [435]	validation_0-auc:0.809124	validation_1-auc:0.797905
# [436]	validation_0-auc:0.809188	validation_1-auc:0.797957
# [437]	validation_0-auc:0.809426	validation_1-auc:0.798118
# [438]	validation_0-auc:0.809424	validation_1-auc:0.798111
# [439]	validation_0-auc:0.809456	validation_1-auc:0.798192
# [440]	validation_0-auc:0.809807	validation_1-auc:0.798467
# [441]	validation_0-auc:0.809923	validation_1-auc:0.798593
# [442]	validation_0-auc:0.810108	validation_1-auc:0.798702
# [443]	validation_0-auc:0.810311	validation_1-auc:0.798984
# [444]	validation_0-auc:0.810336	validation_1-auc:0.799016
# [445]	validation_0-auc:0.810455	validation_1-auc:0.799113
# [446]	validation_0-auc:0.81065	validation_1-auc:0.799296
# [447]	validation_0-auc:0.810812	validation_1-auc:0.799438
# [448]	validation_0-auc:0.810934	validation_1-auc:0.799517
# [449]	validation_0-auc:0.811293	validation_1-auc:0.800029
# [450]	validation_0-auc:0.81144	validation_1-auc:0.800085
# [451]	validation_0-auc:0.811433	validation_1-auc:0.800078
# [452]	validation_0-auc:0.811714	validation_1-auc:0.800382
# [453]	validation_0-auc:0.811841	validation_1-auc:0.80043
# [454]	validation_0-auc:0.81221	validation_1-auc:0.800774
# [455]	validation_0-auc:0.812467	validation_1-auc:0.801058
# [456]	validation_0-auc:0.812622	validation_1-auc:0.80125
# [457]	validation_0-auc:0.812786	validation_1-auc:0.801499
# [458]	validation_0-auc:0.812915	validation_1-auc:0.801529
# [459]	validation_0-auc:0.813025	validation_1-auc:0.801641
# [460]	validation_0-auc:0.813077	validation_1-auc:0.801684
# [461]	validation_0-auc:0.81308	validation_1-auc:0.801687
# [462]	validation_0-auc:0.813087	validation_1-auc:0.801697
# [463]	validation_0-auc:0.81324	validation_1-auc:0.801834
# [464]	validation_0-auc:0.813466	validation_1-auc:0.802101
# [465]	validation_0-auc:0.813621	validation_1-auc:0.802197
# [466]	validation_0-auc:0.813629	validation_1-auc:0.802209
# [467]	validation_0-auc:0.813647	validation_1-auc:0.802209
# [468]	validation_0-auc:0.81381	validation_1-auc:0.802402
# [469]	validation_0-auc:0.814046	validation_1-auc:0.802577
# [470]	validation_0-auc:0.814194	validation_1-auc:0.802761
# [471]	validation_0-auc:0.814403	validation_1-auc:0.802922
# [472]	validation_0-auc:0.814483	validation_1-auc:0.802948
# [473]	validation_0-auc:0.814662	validation_1-auc:0.803147
# [474]	validation_0-auc:0.814739	validation_1-auc:0.803198
# [475]	validation_0-auc:0.814805	validation_1-auc:0.803288
# [476]	validation_0-auc:0.815019	validation_1-auc:0.803468
# [477]	validation_0-auc:0.815028	validation_1-auc:0.803476
# [478]	validation_0-auc:0.815084	validation_1-auc:0.803549
# [479]	validation_0-auc:0.815447	validation_1-auc:0.804061
# [480]	validation_0-auc:0.815627	validation_1-auc:0.804197
# [481]	validation_0-auc:0.815746	validation_1-auc:0.80433
# [482]	validation_0-auc:0.815952	validation_1-auc:0.804452
# [483]	validation_0-auc:0.815959	validation_1-auc:0.804462
# [484]	validation_0-auc:0.815961	validation_1-auc:0.804464
# [485]	validation_0-auc:0.815964	validation_1-auc:0.804465
# [486]	validation_0-auc:0.816083	validation_1-auc:0.804571
# [487]	validation_0-auc:0.81616	validation_1-auc:0.804619
# [488]	validation_0-auc:0.816378	validation_1-auc:0.804793
# [489]	validation_0-auc:0.816813	validation_1-auc:0.805169
# [490]	validation_0-auc:0.816971	validation_1-auc:0.805281
# [491]	validation_0-auc:0.817234	validation_1-auc:0.80557
# [492]	validation_0-auc:0.817366	validation_1-auc:0.805604
# [493]	validation_0-auc:0.817503	validation_1-auc:0.805726
# [494]	validation_0-auc:0.817781	validation_1-auc:0.806065
# [495]	validation_0-auc:0.817937	validation_1-auc:0.806184
# [496]	validation_0-auc:0.818129	validation_1-auc:0.806435
# [497]	validation_0-auc:0.818213	validation_1-auc:0.806594
# [498]	validation_0-auc:0.818294	validation_1-auc:0.806668
# [499]	validation_0-auc:0.818467	validation_1-auc:0.806855
# [500]	validation_0-auc:0.818735	validation_1-auc:0.807068
# [501]	validation_0-auc:0.818896	validation_1-auc:0.807178
# [502]	validation_0-auc:0.818933	validation_1-auc:0.807275
# [503]	validation_0-auc:0.818987	validation_1-auc:0.807326
# [504]	validation_0-auc:0.818997	validation_1-auc:0.80734
# [505]	validation_0-auc:0.819118	validation_1-auc:0.807478
# [506]	validation_0-auc:0.819225	validation_1-auc:0.807521
# [507]	validation_0-auc:0.819433	validation_1-auc:0.807721
# [508]	validation_0-auc:0.819493	validation_1-auc:0.807743
# [509]	validation_0-auc:0.819595	validation_1-auc:0.807742
# [510]	validation_0-auc:0.819749	validation_1-auc:0.807977
# [511]	validation_0-auc:0.819826	validation_1-auc:0.808004
# [512]	validation_0-auc:0.819889	validation_1-auc:0.808073
# [513]	validation_0-auc:0.82003	validation_1-auc:0.808181
# [514]	validation_0-auc:0.820094	validation_1-auc:0.808255
# [515]	validation_0-auc:0.820234	validation_1-auc:0.808402
# [516]	validation_0-auc:0.820446	validation_1-auc:0.80854
# [517]	validation_0-auc:0.820728	validation_1-auc:0.80888
# [518]	validation_0-auc:0.820727	validation_1-auc:0.808874
# [519]	validation_0-auc:0.820747	validation_1-auc:0.808896
# [520]	validation_0-auc:0.82076	validation_1-auc:0.808916
# [521]	validation_0-auc:0.820782	validation_1-auc:0.80894
# [522]	validation_0-auc:0.820982	validation_1-auc:0.809079
# [523]	validation_0-auc:0.821159	validation_1-auc:0.80921
# [524]	validation_0-auc:0.821304	validation_1-auc:0.809468
# [525]	validation_0-auc:0.821493	validation_1-auc:0.809738
# [526]	validation_0-auc:0.821551	validation_1-auc:0.809676
# [527]	validation_0-auc:0.821859	validation_1-auc:0.810008
# [528]	validation_0-auc:0.822055	validation_1-auc:0.81017
# [529]	validation_0-auc:0.822099	validation_1-auc:0.810185
# [530]	validation_0-auc:0.822261	validation_1-auc:0.810335
# [531]	validation_0-auc:0.822353	validation_1-auc:0.810441
# [532]	validation_0-auc:0.822354	validation_1-auc:0.810441
# [533]	validation_0-auc:0.822463	validation_1-auc:0.810619
# [534]	validation_0-auc:0.822519	validation_1-auc:0.81068
# [535]	validation_0-auc:0.822664	validation_1-auc:0.810824
# [536]	validation_0-auc:0.823041	validation_1-auc:0.811286
# [537]	validation_0-auc:0.823139	validation_1-auc:0.811382
# [538]	validation_0-auc:0.82328	validation_1-auc:0.811477
# [539]	validation_0-auc:0.8236	validation_1-auc:0.811785
# [540]	validation_0-auc:0.823736	validation_1-auc:0.81198
# [541]	validation_0-auc:0.8238	validation_1-auc:0.811977
# [542]	validation_0-auc:0.82392	validation_1-auc:0.812107
# [543]	validation_0-auc:0.824072	validation_1-auc:0.812245
# [544]	validation_0-auc:0.824222	validation_1-auc:0.812454
# [545]	validation_0-auc:0.824452	validation_1-auc:0.812724
# [546]	validation_0-auc:0.824595	validation_1-auc:0.812829
# [547]	validation_0-auc:0.824677	validation_1-auc:0.812905
# [548]	validation_0-auc:0.824773	validation_1-auc:0.813062
# [549]	validation_0-auc:0.824786	validation_1-auc:0.813069
# [550]	validation_0-auc:0.824886	validation_1-auc:0.813161
# [551]	validation_0-auc:0.825079	validation_1-auc:0.813357
# [552]	validation_0-auc:0.825196	validation_1-auc:0.8134
# [553]	validation_0-auc:0.825298	validation_1-auc:0.813491
# [554]	validation_0-auc:0.825471	validation_1-auc:0.813613
# [555]	validation_0-auc:0.825543	validation_1-auc:0.813661
# [556]	validation_0-auc:0.825752	validation_1-auc:0.813767
# [557]	validation_0-auc:0.826042	validation_1-auc:0.814128
# [558]	validation_0-auc:0.826282	validation_1-auc:0.814428
# [559]	validation_0-auc:0.826516	validation_1-auc:0.814701
# [560]	validation_0-auc:0.826525	validation_1-auc:0.814712
# [561]	validation_0-auc:0.826654	validation_1-auc:0.81481
# [562]	validation_0-auc:0.826829	validation_1-auc:0.814935
# [563]	validation_0-auc:0.826967	validation_1-auc:0.815
# [564]	validation_0-auc:0.827	validation_1-auc:0.815051
# [565]	validation_0-auc:0.827288	validation_1-auc:0.815322
# [566]	validation_0-auc:0.827288	validation_1-auc:0.815324
# [567]	validation_0-auc:0.827326	validation_1-auc:0.81536
# [568]	validation_0-auc:0.827331	validation_1-auc:0.815361
# [569]	validation_0-auc:0.82742	validation_1-auc:0.815479
# [570]	validation_0-auc:0.827553	validation_1-auc:0.815576
# [571]	validation_0-auc:0.827795	validation_1-auc:0.815788
# [572]	validation_0-auc:0.827936	validation_1-auc:0.81592
# [573]	validation_0-auc:0.828193	validation_1-auc:0.816246
# [574]	validation_0-auc:0.828389	validation_1-auc:0.8165
# [575]	validation_0-auc:0.828479	validation_1-auc:0.816574
# [576]	validation_0-auc:0.82848	validation_1-auc:0.816585
# [577]	validation_0-auc:0.828623	validation_1-auc:0.816725
# [578]	validation_0-auc:0.82872	validation_1-auc:0.816799
# [579]	validation_0-auc:0.828889	validation_1-auc:0.816988
# [580]	validation_0-auc:0.828965	validation_1-auc:0.817034
# [581]	validation_0-auc:0.829182	validation_1-auc:0.817238
# [582]	validation_0-auc:0.829393	validation_1-auc:0.817355
# [583]	validation_0-auc:0.829556	validation_1-auc:0.817684
# [584]	validation_0-auc:0.829765	validation_1-auc:0.817925
# [585]	validation_0-auc:0.829916	validation_1-auc:0.818022
# [586]	validation_0-auc:0.830024	validation_1-auc:0.818181
# [587]	validation_0-auc:0.830147	validation_1-auc:0.818309
# [588]	validation_0-auc:0.830163	validation_1-auc:0.818318
# [589]	validation_0-auc:0.830328	validation_1-auc:0.818571
# [590]	validation_0-auc:0.830439	validation_1-auc:0.818587
# [591]	validation_0-auc:0.830447	validation_1-auc:0.81863
# [592]	validation_0-auc:0.83067	validation_1-auc:0.818857
# [593]	validation_0-auc:0.830836	validation_1-auc:0.819049
# [594]	validation_0-auc:0.830821	validation_1-auc:0.81904
# [595]	validation_0-auc:0.830858	validation_1-auc:0.819075
# [596]	validation_0-auc:0.830994	validation_1-auc:0.819191
# [597]	validation_0-auc:0.831113	validation_1-auc:0.819276
# [598]	validation_0-auc:0.831119	validation_1-auc:0.819279
# [599]	validation_0-auc:0.831132	validation_1-auc:0.819293
# [600]	validation_0-auc:0.831133	validation_1-auc:0.819291
# [601]	validation_0-auc:0.831222	validation_1-auc:0.819354
# [602]	validation_0-auc:0.831234	validation_1-auc:0.819359
# [603]	validation_0-auc:0.831264	validation_1-auc:0.819395
# [604]	validation_0-auc:0.831306	validation_1-auc:0.819474
# [605]	validation_0-auc:0.831479	validation_1-auc:0.819673
# [606]	validation_0-auc:0.831483	validation_1-auc:0.819674
# [607]	validation_0-auc:0.831563	validation_1-auc:0.819749
# [608]	validation_0-auc:0.831728	validation_1-auc:0.819989
# [609]	validation_0-auc:0.831868	validation_1-auc:0.820011
# [610]	validation_0-auc:0.831895	validation_1-auc:0.820069
# [611]	validation_0-auc:0.831904	validation_1-auc:0.82008
# [612]	validation_0-auc:0.831923	validation_1-auc:0.820098
# [613]	validation_0-auc:0.83199	validation_1-auc:0.820125
# [614]	validation_0-auc:0.8321	validation_1-auc:0.820201
# [615]	validation_0-auc:0.832104	validation_1-auc:0.820198
# [616]	validation_0-auc:0.832243	validation_1-auc:0.820315
# [617]	validation_0-auc:0.832312	validation_1-auc:0.820357
# [618]	validation_0-auc:0.83239	validation_1-auc:0.820461
# [619]	validation_0-auc:0.832502	validation_1-auc:0.820573
# [620]	validation_0-auc:0.832513	validation_1-auc:0.820584
# [621]	validation_0-auc:0.832818	validation_1-auc:0.820906
# [622]	validation_0-auc:0.83297	validation_1-auc:0.82109
# [623]	validation_0-auc:0.833126	validation_1-auc:0.821214
# [624]	validation_0-auc:0.833177	validation_1-auc:0.821279
# [625]	validation_0-auc:0.833175	validation_1-auc:0.82128
# [626]	validation_0-auc:0.83318	validation_1-auc:0.821285
# [627]	validation_0-auc:0.833188	validation_1-auc:0.821285
# [628]	validation_0-auc:0.833185	validation_1-auc:0.821287
# [629]	validation_0-auc:0.833392	validation_1-auc:0.821547
# [630]	validation_0-auc:0.833556	validation_1-auc:0.821673
# [631]	validation_0-auc:0.833668	validation_1-auc:0.821842
# [632]	validation_0-auc:0.833757	validation_1-auc:0.821946
# [633]	validation_0-auc:0.833853	validation_1-auc:0.822012
# [634]	validation_0-auc:0.834045	validation_1-auc:0.822065
# [635]	validation_0-auc:0.834208	validation_1-auc:0.822299
# [636]	validation_0-auc:0.834383	validation_1-auc:0.82253
# [637]	validation_0-auc:0.834418	validation_1-auc:0.822552
# [638]	validation_0-auc:0.83456	validation_1-auc:0.822683
# [639]	validation_0-auc:0.834783	validation_1-auc:0.822971
# [640]	validation_0-auc:0.835095	validation_1-auc:0.82317
# [641]	validation_0-auc:0.835308	validation_1-auc:0.823344
# [642]	validation_0-auc:0.835322	validation_1-auc:0.823356
# [643]	validation_0-auc:0.835328	validation_1-auc:0.823362
# [644]	validation_0-auc:0.835512	validation_1-auc:0.823584
# [645]	validation_0-auc:0.835544	validation_1-auc:0.82361
# [646]	validation_0-auc:0.835599	validation_1-auc:0.823684
# [647]	validation_0-auc:0.835693	validation_1-auc:0.823766
# [648]	validation_0-auc:0.835883	validation_1-auc:0.82401
# [649]	validation_0-auc:0.835886	validation_1-auc:0.824011
# [650]	validation_0-auc:0.83594	validation_1-auc:0.824055
# [651]	validation_0-auc:0.836119	validation_1-auc:0.824191
# [652]	validation_0-auc:0.83619	validation_1-auc:0.824233
# [653]	validation_0-auc:0.836348	validation_1-auc:0.824341
# [654]	validation_0-auc:0.836445	validation_1-auc:0.824466
# [655]	validation_0-auc:0.836598	validation_1-auc:0.824694
# [656]	validation_0-auc:0.836664	validation_1-auc:0.824687
# [657]	validation_0-auc:0.836704	validation_1-auc:0.824724
# [658]	validation_0-auc:0.836899	validation_1-auc:0.824879
# [659]	validation_0-auc:0.837042	validation_1-auc:0.82508
# [660]	validation_0-auc:0.837177	validation_1-auc:0.825216
# [661]	validation_0-auc:0.837272	validation_1-auc:0.825297
# [662]	validation_0-auc:0.837321	validation_1-auc:0.825329
# [663]	validation_0-auc:0.837468	validation_1-auc:0.825433
# [664]	validation_0-auc:0.837554	validation_1-auc:0.825521
# [665]	validation_0-auc:0.837648	validation_1-auc:0.825603
# [666]	validation_0-auc:0.837785	validation_1-auc:0.825686
# [667]	validation_0-auc:0.837917	validation_1-auc:0.825811
# [668]	validation_0-auc:0.837957	validation_1-auc:0.825862
# [669]	validation_0-auc:0.837962	validation_1-auc:0.825862
# [670]	validation_0-auc:0.83822	validation_1-auc:0.826036
# [671]	validation_0-auc:0.83835	validation_1-auc:0.826313
# [672]	validation_0-auc:0.838478	validation_1-auc:0.826373
# [673]	validation_0-auc:0.838649	validation_1-auc:0.826561
# [674]	validation_0-auc:0.838886	validation_1-auc:0.826797
# [675]	validation_0-auc:0.839141	validation_1-auc:0.826977
# [676]	validation_0-auc:0.839215	validation_1-auc:0.827048
# [677]	validation_0-auc:0.839434	validation_1-auc:0.827127
# [678]	validation_0-auc:0.839477	validation_1-auc:0.827154
# [679]	validation_0-auc:0.839627	validation_1-auc:0.827288
# [680]	validation_0-auc:0.839648	validation_1-auc:0.827309
# [681]	validation_0-auc:0.839646	validation_1-auc:0.827321
# [682]	validation_0-auc:0.83979	validation_1-auc:0.827478
# [683]	validation_0-auc:0.839823	validation_1-auc:0.827523
# [684]	validation_0-auc:0.840089	validation_1-auc:0.82777
# [685]	validation_0-auc:0.840257	validation_1-auc:0.827936
# [686]	validation_0-auc:0.840265	validation_1-auc:0.827944
# [687]	validation_0-auc:0.840481	validation_1-auc:0.828081
# [688]	validation_0-auc:0.840487	validation_1-auc:0.82805
# [689]	validation_0-auc:0.840566	validation_1-auc:0.828132
# [690]	validation_0-auc:0.840691	validation_1-auc:0.828239
# [691]	validation_0-auc:0.840946	validation_1-auc:0.828373
# [692]	validation_0-auc:0.841058	validation_1-auc:0.828509
# [693]	validation_0-auc:0.841319	validation_1-auc:0.828765
# [694]	validation_0-auc:0.841406	validation_1-auc:0.828871
# [695]	validation_0-auc:0.841438	validation_1-auc:0.82894
# [696]	validation_0-auc:0.841567	validation_1-auc:0.82908
# [697]	validation_0-auc:0.841589	validation_1-auc:0.829102
# [698]	validation_0-auc:0.841612	validation_1-auc:0.829037
# [699]	validation_0-auc:0.841647	validation_1-auc:0.829036
# [700]	validation_0-auc:0.841687	validation_1-auc:0.829086
# [701]	validation_0-auc:0.841875	validation_1-auc:0.829296
# [702]	validation_0-auc:0.84194	validation_1-auc:0.829367
# [703]	validation_0-auc:0.841972	validation_1-auc:0.829414
# [704]	validation_0-auc:0.842152	validation_1-auc:0.829511
# [705]	validation_0-auc:0.84222	validation_1-auc:0.829564
# [706]	validation_0-auc:0.842452	validation_1-auc:0.829789
# [707]	validation_0-auc:0.84245	validation_1-auc:0.829784
# [708]	validation_0-auc:0.842451	validation_1-auc:0.829781
# [709]	validation_0-auc:0.842527	validation_1-auc:0.829911
# [710]	validation_0-auc:0.842595	validation_1-auc:0.829977
# [711]	validation_0-auc:0.842605	validation_1-auc:0.829972
# [712]	validation_0-auc:0.842615	validation_1-auc:0.829979
# [713]	validation_0-auc:0.842655	validation_1-auc:0.829997
# [714]	validation_0-auc:0.842661	validation_1-auc:0.830001
# [715]	validation_0-auc:0.842772	validation_1-auc:0.830153
# [716]	validation_0-auc:0.842879	validation_1-auc:0.830285
# [717]	validation_0-auc:0.842939	validation_1-auc:0.830336
# [718]	validation_0-auc:0.843086	validation_1-auc:0.830504
# [719]	validation_0-auc:0.843207	validation_1-auc:0.830577
# [720]	validation_0-auc:0.843407	validation_1-auc:0.830787
# [721]	validation_0-auc:0.843476	validation_1-auc:0.830866
# [722]	validation_0-auc:0.843568	validation_1-auc:0.830958
# [723]	validation_0-auc:0.843663	validation_1-auc:0.831014
# [724]	validation_0-auc:0.843768	validation_1-auc:0.831031
# [725]	validation_0-auc:0.843955	validation_1-auc:0.83117
# [726]	validation_0-auc:0.844122	validation_1-auc:0.831357
# [727]	validation_0-auc:0.844158	validation_1-auc:0.831408
# [728]	validation_0-auc:0.844306	validation_1-auc:0.831504
# [729]	validation_0-auc:0.844506	validation_1-auc:0.831683
# [730]	validation_0-auc:0.844709	validation_1-auc:0.831783
# [731]	validation_0-auc:0.844795	validation_1-auc:0.831874
# [732]	validation_0-auc:0.844841	validation_1-auc:0.83195
# [733]	validation_0-auc:0.844953	validation_1-auc:0.832042
# [734]	validation_0-auc:0.845089	validation_1-auc:0.832186
# [735]	validation_0-auc:0.845254	validation_1-auc:0.832392
# [736]	validation_0-auc:0.845254	validation_1-auc:0.832395
# [737]	validation_0-auc:0.845255	validation_1-auc:0.832397
# [738]	validation_0-auc:0.84545	validation_1-auc:0.832589
# [739]	validation_0-auc:0.845553	validation_1-auc:0.832701
# [740]	validation_0-auc:0.84563	validation_1-auc:0.832778
# [741]	validation_0-auc:0.845714	validation_1-auc:0.832811
# [742]	validation_0-auc:0.845844	validation_1-auc:0.832953
# [743]	validation_0-auc:0.84599	validation_1-auc:0.833113
# [744]	validation_0-auc:0.846057	validation_1-auc:0.833153
# [745]	validation_0-auc:0.846081	validation_1-auc:0.833191
# [746]	validation_0-auc:0.84615	validation_1-auc:0.833221
# [747]	validation_0-auc:0.846247	validation_1-auc:0.83334
# [748]	validation_0-auc:0.846313	validation_1-auc:0.833409
# [749]	validation_0-auc:0.846463	validation_1-auc:0.833606
# [750]	validation_0-auc:0.846534	validation_1-auc:0.83364
# [751]	validation_0-auc:0.846673	validation_1-auc:0.833759
# [752]	validation_0-auc:0.846738	validation_1-auc:0.833833
# [753]	validation_0-auc:0.846774	validation_1-auc:0.833914
# [754]	validation_0-auc:0.846945	validation_1-auc:0.83399
# [755]	validation_0-auc:0.847204	validation_1-auc:0.834239
# [756]	validation_0-auc:0.847315	validation_1-auc:0.834342
# [757]	validation_0-auc:0.847417	validation_1-auc:0.834378
# [758]	validation_0-auc:0.847535	validation_1-auc:0.834425
# [759]	validation_0-auc:0.847701	validation_1-auc:0.834614
# [760]	validation_0-auc:0.847806	validation_1-auc:0.834697
# [761]	validation_0-auc:0.847869	validation_1-auc:0.83474
# [762]	validation_0-auc:0.847927	validation_1-auc:0.83481
# [763]	validation_0-auc:0.847969	validation_1-auc:0.834848
# [764]	validation_0-auc:0.847975	validation_1-auc:0.834863
# [765]	validation_0-auc:0.847989	validation_1-auc:0.83482
# [766]	validation_0-auc:0.84807	validation_1-auc:0.834879
# [767]	validation_0-auc:0.848195	validation_1-auc:0.834963
# [768]	validation_0-auc:0.848197	validation_1-auc:0.834964
# [769]	validation_0-auc:0.848321	validation_1-auc:0.835051
# [770]	validation_0-auc:0.848436	validation_1-auc:0.835137
# [771]	validation_0-auc:0.848463	validation_1-auc:0.83519
# [772]	validation_0-auc:0.848492	validation_1-auc:0.835235
# [773]	validation_0-auc:0.848717	validation_1-auc:0.835532
# [774]	validation_0-auc:0.84875	validation_1-auc:0.835536
# [775]	validation_0-auc:0.848838	validation_1-auc:0.835616
# [776]	validation_0-auc:0.848878	validation_1-auc:0.835643
# [777]	validation_0-auc:0.84896	validation_1-auc:0.835758
# [778]	validation_0-auc:0.849066	validation_1-auc:0.83585
# [779]	validation_0-auc:0.84923	validation_1-auc:0.836085
# [780]	validation_0-auc:0.849343	validation_1-auc:0.836133
# [781]	validation_0-auc:0.849408	validation_1-auc:0.836201
# [782]	validation_0-auc:0.849485	validation_1-auc:0.83624
# [783]	validation_0-auc:0.849605	validation_1-auc:0.836333
# [784]	validation_0-auc:0.849606	validation_1-auc:0.836331
# [785]	validation_0-auc:0.849674	validation_1-auc:0.836368
# [786]	validation_0-auc:0.849801	validation_1-auc:0.836518
# [787]	validation_0-auc:0.849799	validation_1-auc:0.836516
# [788]	validation_0-auc:0.849864	validation_1-auc:0.83658
# [789]	validation_0-auc:0.849866	validation_1-auc:0.83658
# [790]	validation_0-auc:0.850012	validation_1-auc:0.836746
# [791]	validation_0-auc:0.850147	validation_1-auc:0.836905
# [792]	validation_0-auc:0.850245	validation_1-auc:0.83702
# [793]	validation_0-auc:0.85033	validation_1-auc:0.837063
# [794]	validation_0-auc:0.850384	validation_1-auc:0.837069
# [795]	validation_0-auc:0.850625	validation_1-auc:0.837305
# [796]	validation_0-auc:0.850623	validation_1-auc:0.837303
# [797]	validation_0-auc:0.850655	validation_1-auc:0.837312
# [798]	validation_0-auc:0.850688	validation_1-auc:0.837336
# [799]	validation_0-auc:0.850698	validation_1-auc:0.837365
# [800]	validation_0-auc:0.850793	validation_1-auc:0.837495
# [801]	validation_0-auc:0.850803	validation_1-auc:0.837499
# [802]	validation_0-auc:0.850806	validation_1-auc:0.8375
# [803]	validation_0-auc:0.850808	validation_1-auc:0.837509
# [804]	validation_0-auc:0.851011	validation_1-auc:0.837798
# [805]	validation_0-auc:0.851081	validation_1-auc:0.837853
# [806]	validation_0-auc:0.85118	validation_1-auc:0.837925
# [807]	validation_0-auc:0.851264	validation_1-auc:0.837951
# [808]	validation_0-auc:0.851344	validation_1-auc:0.837993
# [809]	validation_0-auc:0.851429	validation_1-auc:0.838062
# [810]	validation_0-auc:0.851568	validation_1-auc:0.838248
# [811]	validation_0-auc:0.851706	validation_1-auc:0.838383
# [812]	validation_0-auc:0.851768	validation_1-auc:0.8384
# [813]	validation_0-auc:0.851897	validation_1-auc:0.838529
# [814]	validation_0-auc:0.852012	validation_1-auc:0.838577
# [815]	validation_0-auc:0.852015	validation_1-auc:0.838577
# [816]	validation_0-auc:0.852039	validation_1-auc:0.838614
# [817]	validation_0-auc:0.85204	validation_1-auc:0.838612
# [818]	validation_0-auc:0.852122	validation_1-auc:0.838649
# [819]	validation_0-auc:0.852274	validation_1-auc:0.838742
# [820]	validation_0-auc:0.852368	validation_1-auc:0.838807
# [821]	validation_0-auc:0.852397	validation_1-auc:0.838811
# [822]	validation_0-auc:0.852503	validation_1-auc:0.838952
# [823]	validation_0-auc:0.852561	validation_1-auc:0.838989
# [824]	validation_0-auc:0.852662	validation_1-auc:0.839114
# [825]	validation_0-auc:0.852794	validation_1-auc:0.839243
# [826]	validation_0-auc:0.85292	validation_1-auc:0.839349
# [827]	validation_0-auc:0.853067	validation_1-auc:0.839492
# [828]	validation_0-auc:0.853206	validation_1-auc:0.839681
# [829]	validation_0-auc:0.853412	validation_1-auc:0.839897
# [830]	validation_0-auc:0.85346	validation_1-auc:0.839918
# [831]	validation_0-auc:0.853537	validation_1-auc:0.840006
# [832]	validation_0-auc:0.853643	validation_1-auc:0.840077
# [833]	validation_0-auc:0.853647	validation_1-auc:0.840074
# [834]	validation_0-auc:0.853648	validation_1-auc:0.840072
# [835]	validation_0-auc:0.853774	validation_1-auc:0.840159
# [836]	validation_0-auc:0.853857	validation_1-auc:0.840214
# [837]	validation_0-auc:0.854051	validation_1-auc:0.840425
# [838]	validation_0-auc:0.854179	validation_1-auc:0.840537
# [839]	validation_0-auc:0.854225	validation_1-auc:0.840588
# [840]	validation_0-auc:0.854418	validation_1-auc:0.840758
# [841]	validation_0-auc:0.854464	validation_1-auc:0.840765
# [842]	validation_0-auc:0.854463	validation_1-auc:0.840771
# [843]	validation_0-auc:0.854544	validation_1-auc:0.84076
# [844]	validation_0-auc:0.854608	validation_1-auc:0.840791
# [845]	validation_0-auc:0.854666	validation_1-auc:0.840863
# [846]	validation_0-auc:0.854823	validation_1-auc:0.841039
# [847]	validation_0-auc:0.854886	validation_1-auc:0.841128
# [848]	validation_0-auc:0.855084	validation_1-auc:0.841396
# [849]	validation_0-auc:0.855217	validation_1-auc:0.841559
# [850]	validation_0-auc:0.855313	validation_1-auc:0.841655
# [851]	validation_0-auc:0.855349	validation_1-auc:0.841653
# [852]	validation_0-auc:0.855404	validation_1-auc:0.841706
# [853]	validation_0-auc:0.855408	validation_1-auc:0.841696
# [854]	validation_0-auc:0.855405	validation_1-auc:0.841692
# [855]	validation_0-auc:0.855422	validation_1-auc:0.841707
# [856]	validation_0-auc:0.855496	validation_1-auc:0.841733
# [857]	validation_0-auc:0.855497	validation_1-auc:0.841718
# [858]	validation_0-auc:0.855523	validation_1-auc:0.84175
# [859]	validation_0-auc:0.85553	validation_1-auc:0.841754
# [860]	validation_0-auc:0.855686	validation_1-auc:0.841925
# [861]	validation_0-auc:0.855686	validation_1-auc:0.841926
# [862]	validation_0-auc:0.85584	validation_1-auc:0.842098
# [863]	validation_0-auc:0.855919	validation_1-auc:0.842181
# [864]	validation_0-auc:0.85597	validation_1-auc:0.842226
# [865]	validation_0-auc:0.856007	validation_1-auc:0.84226
# [866]	validation_0-auc:0.85618	validation_1-auc:0.842271
# [867]	validation_0-auc:0.856218	validation_1-auc:0.842275
# [868]	validation_0-auc:0.856334	validation_1-auc:0.842407
# [869]	validation_0-auc:0.856394	validation_1-auc:0.842453
# [870]	validation_0-auc:0.856556	validation_1-auc:0.842632
# [871]	validation_0-auc:0.856611	validation_1-auc:0.842712
# [872]	validation_0-auc:0.856652	validation_1-auc:0.842786
# [873]	validation_0-auc:0.856653	validation_1-auc:0.842787
# [874]	validation_0-auc:0.85674	validation_1-auc:0.842858
# [875]	validation_0-auc:0.856742	validation_1-auc:0.842859
# [876]	validation_0-auc:0.856809	validation_1-auc:0.842884
# [877]	validation_0-auc:0.856809	validation_1-auc:0.842886
# [878]	validation_0-auc:0.856809	validation_1-auc:0.842886
# [879]	validation_0-auc:0.856971	validation_1-auc:0.843022
# [880]	validation_0-auc:0.856976	validation_1-auc:0.843019
# [881]	validation_0-auc:0.857096	validation_1-auc:0.843162
# [882]	validation_0-auc:0.857142	validation_1-auc:0.843167
# [883]	validation_0-auc:0.857144	validation_1-auc:0.843156
# [884]	validation_0-auc:0.857209	validation_1-auc:0.843143
# [885]	validation_0-auc:0.857382	validation_1-auc:0.843259
# [886]	validation_0-auc:0.857375	validation_1-auc:0.843289
# [887]	validation_0-auc:0.857405	validation_1-auc:0.843262
# [888]	validation_0-auc:0.857494	validation_1-auc:0.843313
# [889]	validation_0-auc:0.857552	validation_1-auc:0.843362
# [890]	validation_0-auc:0.857629	validation_1-auc:0.843429
# [891]	validation_0-auc:0.857719	validation_1-auc:0.843503
# [892]	validation_0-auc:0.857822	validation_1-auc:0.843654
# [893]	validation_0-auc:0.857959	validation_1-auc:0.843832
# [894]	validation_0-auc:0.858084	validation_1-auc:0.84396
# [895]	validation_0-auc:0.858243	validation_1-auc:0.844105
# [896]	validation_0-auc:0.858327	validation_1-auc:0.844139
# [897]	validation_0-auc:0.858474	validation_1-auc:0.844311
# [898]	validation_0-auc:0.85856	validation_1-auc:0.844411
# [899]	validation_0-auc:0.858684	validation_1-auc:0.844514
# [900]	validation_0-auc:0.858749	validation_1-auc:0.844564
# [901]	validation_0-auc:0.858824	validation_1-auc:0.84465
# [902]	validation_0-auc:0.858822	validation_1-auc:0.84465
# [903]	validation_0-auc:0.858873	validation_1-auc:0.84473
# [904]	validation_0-auc:0.85896	validation_1-auc:0.844852
# [905]	validation_0-auc:0.859032	validation_1-auc:0.844929
# [906]	validation_0-auc:0.859087	validation_1-auc:0.844984
# [907]	validation_0-auc:0.8591	validation_1-auc:0.844999
# [908]	validation_0-auc:0.859102	validation_1-auc:0.845002
# [909]	validation_0-auc:0.859208	validation_1-auc:0.845048
# [910]	validation_0-auc:0.859325	validation_1-auc:0.845128
# [911]	validation_0-auc:0.859502	validation_1-auc:0.845304
# [912]	validation_0-auc:0.859523	validation_1-auc:0.845274
# [913]	validation_0-auc:0.859622	validation_1-auc:0.845393
# [914]	validation_0-auc:0.85977	validation_1-auc:0.845493
# [915]	validation_0-auc:0.859841	validation_1-auc:0.845593
# [916]	validation_0-auc:0.859869	validation_1-auc:0.845581
# [917]	validation_0-auc:0.859964	validation_1-auc:0.845692
# [918]	validation_0-auc:0.860022	validation_1-auc:0.845719
# [919]	validation_0-auc:0.860165	validation_1-auc:0.845814
# [920]	validation_0-auc:0.860222	validation_1-auc:0.84588
# [921]	validation_0-auc:0.860319	validation_1-auc:0.845951
# [922]	validation_0-auc:0.860423	validation_1-auc:0.84604
# [923]	validation_0-auc:0.860528	validation_1-auc:0.846155
# [924]	validation_0-auc:0.860528	validation_1-auc:0.846155
# [925]	validation_0-auc:0.860539	validation_1-auc:0.846165
# [926]	validation_0-auc:0.86072	validation_1-auc:0.846281
# [927]	validation_0-auc:0.860798	validation_1-auc:0.846341
# [928]	validation_0-auc:0.860828	validation_1-auc:0.846406
# [929]	validation_0-auc:0.860822	validation_1-auc:0.8464
# [930]	validation_0-auc:0.860828	validation_1-auc:0.846403
# [931]	validation_0-auc:0.860834	validation_1-auc:0.846408
# [932]	validation_0-auc:0.86098	validation_1-auc:0.846562
# [933]	validation_0-auc:0.86108	validation_1-auc:0.846591
# [934]	validation_0-auc:0.861075	validation_1-auc:0.846604
# [935]	validation_0-auc:0.861091	validation_1-auc:0.846647
# [936]	validation_0-auc:0.861094	validation_1-auc:0.846652
# [937]	validation_0-auc:0.861102	validation_1-auc:0.846658
# [938]	validation_0-auc:0.861106	validation_1-auc:0.846667
# [939]	validation_0-auc:0.861105	validation_1-auc:0.846666
# [940]	validation_0-auc:0.86118	validation_1-auc:0.846754
# [941]	validation_0-auc:0.861182	validation_1-auc:0.846756
# [942]	validation_0-auc:0.861283	validation_1-auc:0.846869
# [943]	validation_0-auc:0.861309	validation_1-auc:0.846897
# [944]	validation_0-auc:0.861361	validation_1-auc:0.846903
# [945]	validation_0-auc:0.861486	validation_1-auc:0.847054
# [946]	validation_0-auc:0.861542	validation_1-auc:0.847155
# [947]	validation_0-auc:0.861659	validation_1-auc:0.84725
# [948]	validation_0-auc:0.861693	validation_1-auc:0.847279
# [949]	validation_0-auc:0.861698	validation_1-auc:0.84728
# [950]	validation_0-auc:0.861764	validation_1-auc:0.847372
# [951]	validation_0-auc:0.861918	validation_1-auc:0.847503
# [952]	validation_0-auc:0.861991	validation_1-auc:0.847557
# [953]	validation_0-auc:0.861992	validation_1-auc:0.847559
# [954]	validation_0-auc:0.862014	validation_1-auc:0.847608
# [955]	validation_0-auc:0.862123	validation_1-auc:0.847645
# [956]	validation_0-auc:0.862225	validation_1-auc:0.847718
# [957]	validation_0-auc:0.862295	validation_1-auc:0.847786
# [958]	validation_0-auc:0.86253	validation_1-auc:0.84802
# [959]	validation_0-auc:0.86261	validation_1-auc:0.84814
# [960]	validation_0-auc:0.862617	validation_1-auc:0.84815
# [961]	validation_0-auc:0.862751	validation_1-auc:0.848324
# [962]	validation_0-auc:0.862836	validation_1-auc:0.848379
# [963]	validation_0-auc:0.862885	validation_1-auc:0.848378
# [964]	validation_0-auc:0.862886	validation_1-auc:0.84838
# [965]	validation_0-auc:0.862887	validation_1-auc:0.848363
# [966]	validation_0-auc:0.862935	validation_1-auc:0.848435
# [967]	validation_0-auc:0.862988	validation_1-auc:0.848487
# [968]	validation_0-auc:0.862991	validation_1-auc:0.848506
# [969]	validation_0-auc:0.862983	validation_1-auc:0.848503
# [970]	validation_0-auc:0.862989	validation_1-auc:0.84851
# [971]	validation_0-auc:0.863085	validation_1-auc:0.848616
# [972]	validation_0-auc:0.863191	validation_1-auc:0.848699
# [973]	validation_0-auc:0.8632	validation_1-auc:0.848714
# [974]	validation_0-auc:0.863284	validation_1-auc:0.848765
# [975]	validation_0-auc:0.863312	validation_1-auc:0.848796
# [976]	validation_0-auc:0.863386	validation_1-auc:0.848899
# [977]	validation_0-auc:0.863446	validation_1-auc:0.84897
# [978]	validation_0-auc:0.863597	validation_1-auc:0.849052
# [979]	validation_0-auc:0.863602	validation_1-auc:0.849063
# [980]	validation_0-auc:0.863675	validation_1-auc:0.849145
# [981]	validation_0-auc:0.863737	validation_1-auc:0.849209
# [982]	validation_0-auc:0.863739	validation_1-auc:0.849211
# [983]	validation_0-auc:0.863768	validation_1-auc:0.849242
# [984]	validation_0-auc:0.863774	validation_1-auc:0.849262
# [985]	validation_0-auc:0.863834	validation_1-auc:0.849349
# [986]	validation_0-auc:0.863853	validation_1-auc:0.849355
# [987]	validation_0-auc:0.86396	validation_1-auc:0.849413
# [988]	validation_0-auc:0.864087	validation_1-auc:0.849502
# [989]	validation_0-auc:0.864127	validation_1-auc:0.849578
# [990]	validation_0-auc:0.864204	validation_1-auc:0.849652
# [991]	validation_0-auc:0.86431	validation_1-auc:0.849799
# [992]	validation_0-auc:0.864363	validation_1-auc:0.849834
# [993]	validation_0-auc:0.86446	validation_1-auc:0.849901
# [994]	validation_0-auc:0.86457	validation_1-auc:0.849984
# [995]	validation_0-auc:0.864599	validation_1-auc:0.850042
# [996]	validation_0-auc:0.864725	validation_1-auc:0.850146
# [997]	validation_0-auc:0.864896	validation_1-auc:0.850357
# [998]	validation_0-auc:0.865019	validation_1-auc:0.850513
# [999]	validation_0-auc:0.865085	validation_1-auc:0.850574
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
# Fit the ROC/AUC model on validation datasets. 

from sklearn.metrics import roc_auc_score

class_index = 1

y_pred_proba = model.predict_proba(X_val_processed)[:, class_index]

print(f'Validation ROC AUC for class {class_index}:')
print(roc_auc_score(y_val, y_pred_proba))
# Out:
# Validation ROC AUC for class 1:
# 0.8505743227916603

# %%
X_test_processed = processor.transform(X_test)

class_index = 1

y_pred_proba = model.predict_proba(X_test_processed)[:, class_index]

print(f'Test ROC AUC for class {class_index}:')
print(roc_auc_score(y_test, y_pred_proba))
# Out:
# Test ROC AUC for class 1:
# 0.8577747989276139
